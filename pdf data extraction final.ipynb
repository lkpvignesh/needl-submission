# %%
import os
import pickle
import dill
import re
import numpy as np
import pandas as pd
import textract # package to perform ocr and pdf2text ways of pdf parsing
import pdfminer
from pdfminer.high_level import extract_text
from pdfminer.pdfparser import PDFParser
from pdfminer.pdfdocument import PDFDocument
from validate_email import validate_email
from collections import Counter

# %%
source_path = './data/'
file_list = os.listdir(source_path)
print("Total number of files ",len(file_list))
# Out:
# Total number of files  590

# %%
file_list
# Out:
# ['JPM_022014_14225.pdf',
#  'Deep Industries Ltd - Award of Hiring of Integrated Drilling & Completion Services.pdf',
#  'Industry-Map-of-the-Precious-Metals-Sector.pdf',
#  'Ambit India Access_Pre-Budget conference call with Ashok Wadhwa_03Jul2014.pdf',
#  'ThinkSoft-Corporate-Presentation-Mar-12.pdf',
#  '[Kotak] GlaxoSmithKline Consumer, February 9, 2016.pdf',
#  'JMFL– TCI EXPRESS -errclub- An Express Delivery Company.pdf',
#  'Hotline 93.pdf',
#  'BHFC_Q1FY17ResultUpdate_7 Aug 16.pdf',
#  'GST_-_PROPITIOUS_WINDS_OF_CHANGE-DEC-15-EDEL.pdf',
#  'MaricoKayaEnt.pdf',
#  'business_valuation_methods.pdf',
#  'GRUH_Profile_June_2014.pdf',
#  'Copy of 10 LUXE Cost Sheet.pdf',
#  'ICICI Direct- Company Update – Bharat Electronics (Buy) errclub Reiterate.pdf',
#  'Finolex%20Industries%20Presentation.pdf',
#  'INXW-20170203-MOSL-RU-PG008.pdf',
#  'issue-nov_dec0787[1].pdf',
#  'Timken India Company Update.pdf',
#  '201390164-Prannoy-Roy-s-email-to-Gurumurthy-regarding-Chidambaram-NDTV-s-Rs-5000-crores-money-laundering-scam.pdf',
#  'GC14-4811_2.pdf',
#  'V-guard 1QFY17 Review.pdf',
#  'visitor_brou.pdf',
#  'House of debt.pdf',
#  'JP+Morgan-+Phoenix+Mills+-+Annuity+income+could+grow+4.pdf',
#  'IWEO_2011_lowres.pdf',
#  'Bajaj Corp 4QFY18 Outlook Review.pdf',
#  '2010_analyst_meet_presentation.pdf',
#  'DRRD-20170505-MOSL-CU-PG006.pdf',
#  'Avant Garde Wealth Mgmt - Quarterly letter - 1306.pdf',
#  '20141013_IndusInd-Bank-Limited_204_QuarterUpdate.pdf',
#  'ICRA Sector Updates - Indian Tractor Industry, Aug 2012.pdf',
#  'ECO-CPI-IIP-20180612-MOSL-ES-PG006.pdf',
#  'HFC-23_Policy-Briefing1.pdf',
#  'Ultratech Cement Ltd (ULTC.NS)- Binani Cement Assets- MS.pdf',
#  'EDEL_PULSE-conference_note-Aug-12-EDEL.pdf',
#  'FromAnecdotetoAssessment.pdf',
#  'sunhdfc.pdf',
#  'Corona Audit_Report_2011-12.pdf',
#  'Ambit_Ten Interesting Things_Weeklies_28Mar2018.pdf',
#  'IndusInd Bank-Prabhudas Lilladher Q3FY17 Update.pdf',
#  'India Steel UBS part 2.pdf',
#  'Bigbloc Const.  Investor presentation.pdf',
#  'VIP 1QFY17.pdf',
#  'UPLL-20181026-MOSL-RU-PG012.pdf',
#  'WHIRL-20171127-MOSL-CU-PG006.pdf',
#  'Astral Poly.pdf',
#  'IceCap Asset Management Limited Global Markets November 2011.pdf',
#  'http___www.edelresearch.com_rpt_showPdf.aspx_id=20806&reportname=_BRAVEHEART_SERIES-Zee_Entertainment_Enterprises.pdf',
#  'BLS_International-_2QFY18_-_HDFC_sec.pdf',
#  'Godrej Consumer products.pdf',
#  'AGLL-20170523-MOSL-RU-PG010.pdf',
#  'Antique Broking- Sector Report  Infrastructure & Construction Sector - On the cusp of recovery.pdf',
#  'BP Wealth- Kitex Garments Limited.pdf',
#  'FRC_Study_ETF_Executive%20Summary.pdf',
#  'Annual-Report2017-18.pdf',
#  'MIConferenceBrochure.pdf',
#  'Biocon - BAML.pdf',
#  'BuffettWhartonspeech.pdf',
#  'correspondence2_p.pdf',
#  'IDirect_Concor_Q4FY17.pdf',
#  'Dolat- Rallis India- Key takeaways from the annual report.pdf',
#  'aviationweek.pdf',
#  'KPMG Flash News - New Companies Act, 2013 - Insight Series.pdf',
#  'HIL Ltd - IC - BP Equitiesb.pdf',
#  'Hudgins.pdf',
#  'vedcmd_q_a_transcript.pdf',
#  'The Front Page 20190325.pdf',
#  'Havells India Q1FY14 Result Update.pdf',
#  'Edelweiss Investment Banking_BFSI Newsletter (December  2015).pdf',
#  'Emkay  Chambal Fertilisers Q2FY17 Result Update-074044.pdf',
#  'ICICI Direct- Talwarkar BetterValue.pdf',
#  'Lupin UBS 100816.pdf',
#  'IN_en.pdf',
#  'Banks_NBFCs_-_4QFY17_Results_Preview_-_HDFC_sec.pdf',
#  'Telecom_Vodafone_Idea_merger_Jan17.pdf',
#  'TI Annual Report 08-09.pdf',
#  'The benefits of being a real fraudster - FT.pdf',
#  'IDirect_Greenply_IC.pdf',
#  'kotak ecommerce.pdf',
#  'Space.pdf',
#  'CG Power - Elara-.pdf',
#  'Thomas Cook (I).pdf',
#  'ivey-executive-program.pdf',
#  'Audited Financial Results_30.06.2014.pdf',
#  'IndiaMorningBrief_13June2018.pdf',
#  'ConsumerStaples-17-11-11-PL.pdf',
#  'Ambit - Bajaj Finance (SELL) errclub Steep valuations and rising risks.pdf',
#  'BNK_SONA@IN_021715_161235.pdf',
#  'Career Launcher Investment Kit.pdf',
#  'Citi - India Budget.pdf',
#  'FoE-20180208-MOSL-ES-PG006.pdf',
#  'Balkrishna Inds quant.pdf',
#  'EY-Tax-Alert-key-proposals-of-the-Direct-Taxes-Code-2010%20.pdf',
#  "Millennials to Anchor India's Growth Story.pdf",
#  'Goodyear+India+-+Stock+Note.pdf',
#  'UPL (1QFY19) - HDFC sec.pdf',
#  'ESIB Bajaj Finserve1.pdf',
#  'H016615261.pdf',
#  'It services 2.pdf',
#  'DCM Ltd Report.pdf',
#  '10_chapter 5.pdf',
#  'AMP - 210316.pdf',
#  'Granules_-_2QFY18_-_HDFC_sec.pdf',
#  'Ambit_Walk in the woods_Fortnightly_What we are hearing_18July2018.pdf',
#  'MCX_Edel.pdf',
#  'AR032012.pdf',
#  'Against the Tide.pdf',
#  'Global Logistics.pdf',
#  'APNT-20160727-MOSL-RU-PG008.pdf',
#  'KMB-20141121-MOSL-CU-PG014.pdf',
#  'The Federal Bank Ltd. Insights - Earnings recover, valuation comfortable.pdf',
#  'just dial - 240913 - centrum.pdf',
#  'BHEL 2QFY18 Outlook Review.pdf',
#  'ABD-20150318-MOSL-CF-PG004.pdf',
#  'JUST_1QFY17 result review.pdf',
#  'EDELFLASH_-_FERTILISERS_-_GAS_PRICE_HIKE_TO_IMPACT_ADVERSELY-13-JAN-14.pdf',
#  'BOAML-BhagMilkhaBhag.pdf',
#  'enam_voltas.pdf',
#  'nestle.pdf',
#  'Antique Broking- Management Meet Update India Banking -errclub TransUnion CIBIL - Retail underwriting remain strong.pdf',
#  'DB - UPL.pdf',
#  'Kotak_15Jan16_Consumer_Querimetrix.pdf',
#  'ice cap asset - shoe view - jan14.pdf',
#  'EDEL- Media - Hits ‘n’ Misses errclub Share gains amidst demonetisation blues.pdf',
#  'JMFL– Sun TV Network -errclub- Business becoming more Tamil-centric, stock remains undervalued.pdf',
#  'BAFL MAy 2016 Concall Transcripts.pdf',
#  'India+consumer+sector+Nov+12.pdf',
#  'em_20_anniversary.pdf',
#  'Cement Sector - Monthly Update - 28 Mar 18.pdf',
#  'federal.pdf',
#  'Axis Direct- Aurobindo - In-line EBITDA; US growth visibility remains.pdf',
#  'pn5_2005.pdf',
#  'Kirloskar Oil Engines_IC_5 May 2016.pdf',
#  'Conviction Ideas- Goodricke Group.pdf',
#  'Media_Report_18Sept2017.pdf',
#  'Emkay- Sector Update Automobiles.pdf',
#  'I-Sec_Mn150517.pdf',
#  'AMRJ-20170123-MOSL-RU-PG010.pdf',
#  'BAFL QIP - List of allottees-11062015.pdf',
#  'Wabco India 2QFY18 Outlook Review.pdf',
#  '3TUHR8XDFPGYI62CJ5MQK14LSW7EBO.pdf',
#  'EIL_IDFC - July12 .pdf',
#  'TTKPHARM_20120116.pdf',
#  "V-Guard Transcript Jan'14.pdf",
#  'ICICI UBS.pdf',
#  'r101028a.pdf',
#  'june_2008_ubs_presentation.pdf',
#  'iuu02n30-3osq-g007-bf29-984be168e003.pdf',
#  'IceCapAssetManagementLimitedGlobalMarketsJuly2010.pdf',
#  'BUDGET_PREVIEW_FY14-JUN-14-EDEL.pdf',
#  'La Opala 2011.pdf',
#  'TVSL-20170427-MOSL-RU-PG014.pdf',
#  'Ambit_Ten Interesting Things_Weeklies_25Jan2018.pdf',
#  'GujaratAmbujaExportsLtd (2).pdf',
#  'ICIL_Q2FY16_Investor_Update_Presentation.pdf',
#  'Axis Bank 2QFY19 result update - 181103 - Antique Research.pdf',
#  'AMP - 180502.pdf',
#  'Liberty Shoes Q3FY14 Result Update.pdf',
#  'LT-28-7-17-PL.pdf',
#  'VOLT 1QFY17 Review.pdf',
#  'Colgate Palmolive (India) (COLG.BO) - Citi.pdf',
#  "Waiver loan_19Dec'18.pdf",
#  '2012_india.pdf',
#  'JagranPrakashan151216xe261629.pdf',
#  'Ambit India Access_Little Giants Day_18Dec2017.pdf',
#  'macroperspective.pdf',
#  'Citi- Petronet LNG (PLNG.BO) - 3Q - EBITDA Expectedly Soft, But Volumes Surprise Positively.pdf',
#  'CITUNIBA_20120806.pdf',
#  'Cover Page - EBook Sourajit Aiyer.pdf',
#  'HDFC Sec_Banks & NBFC Sector_Q1FY17 Preview_08072016.pdf',
#  'VP Chemical Presentation.pdf',
#  '2015-08-07_1438962126.pdf',
#  'Axis Direct- AIA Engineering - Mining volumes pick up.pdf',
#  'India Asset Management - Monthly Update - JM Financial.pdf',
#  'GS- Titan Industries (TITN.BO) err In line with expectations Higher margins offset lower Tanishq sales.pdf',
#  'GC14-4880_2.pdf',
#  'IT-20150309-MOSL-WOW-PG006.pdf',
#  'JustDial-IPO - trust.pdf',
#  'CRG 1QFY16 Review.pdf',
#  'ENGG-20141014-MOSL-FC-PG008.pdf',
#  'Conviction Ideas - Raymond.pdf',
#  'TELX-20170127-MOSL-RU-PG010.pdf',
#  'BHE-8-8-16-PL.pdf',
#  'Ambit India Access_Pre-Budget Conference Call with Dinesh Kanabar_25Jan2018.pdf',
#  'AmbitCap-Hathway-Nov19-2013.pdf',
#  'vhf-interim-guidance.pdf',
#  'The Option Trader Handbook - Strategies And Trade Adjustments.pdf',
#  'Cera Presentation.pdf',
#  'Alcoholic_Beverages_Jun162.pdf',
#  'AXSB-20171113-MOSL-CU-PG008.pdf',
#  'IDEA-20170213-MOSL-RU-PG012.pdf',
#  '[Kotak] Telecommunication Services, December 18, 2018.pdf',
#  'ICRA nov 2013.pdf',
#  'UTILITY-DISCOM-20150313-MOSL-ROH-PG014.pdf',
#  'Thejo_RHP_Final.pdf',
#  'Keeping%20Condensers%20Clean%20POWER%200406.pdf',
#  'DrReddys_Flash_290316.pdf',
#  'iSec- VRL Logistics.pdf',
#  'Tyre sector update - 170130.pdf',
#  '2008_03_IR_Book_en (2).pdf',
#  'Cera Sanitaryware Ltd  (2).pdf',
#  'Dollar Industries.pdf',
#  'Info_Edge_Q4FY17.pdf',
#  'Lokusdesign Credentials 200115.pdf',
#  'AmbitInsights_08Aug2016.pdf',
#  'annualreport2002webnew.pdf',
#  'IFB_Industries_Ltd_080814.pdf',
#  'Akzo Nobel-Value Pick.pdf',
#  "India's economy_ How India got its funk _ The Economist.pdf",
#  'lbs061812appendixG.pdf',
#  'Case_Study_8.pdf',
#  'India+Strategy-+The+Gold+Attack+-+Is+it+Strong+Enough.pdf',
#  'GUJGA-20180511-MOSL-RU-PG008.pdf',
#  'Vaibhav Global Ltd - Investor & Analyst Meet Invite - 26 June 2014.pdf',
#  'Ambit Insights_27Apr2018.pdf',
#  'CPBrochure.pdf',
#  'UPL 1QFY19 result update - 180731.pdf',
#  'EDELWEISS_FUND_INSIGHT_NOV-13-EDEL.pdf',
#  'Investor Aug-14.pdf',
#  'Balkrishna Industries Limited - A R 2012-13.pdf',
#  'iEnergy+Theni+Wind+farm+RAC.pdf',
#  'HDFC 1QFY16 Outlook.pdf',
#  'CJ July 2013.pdf',
#  'US Generic - Mar14 .pdf',
#  'Jain_Irrigation_Systems_Ltd_1203121.pdf',
#  '[Kotak] HCL Technologies, October 23, 2018.pdf',
#  'CALCNTUT.pdf',
#  'Kotak UBS 270417.pdf',
#  'Beta Drugs Ltd.pdf',
#  'Cyient Analyst day_final.pdf',
#  'cummins oct 2014.pdf',
#  'CSFEb15.pdf',
#  'Table-1.pdf',
#  'IIFL-+Titan-Gold+standard-ADD.pdf',
#  'ICNT-20151028-MOSL-RU-PG012.pdf',
#  'Vaibhav Global - Investor & Analyst meet presentation.pdf',
#  'INFDEVFC_20150909.pdf',
#  'Hester_8 Page Notice.pdf',
#  'Centrum Wealth - L G  Balakrishnan  Bros  Ltd - Initiating Coverage - 30 June 2015.pdf',
#  'HDFC sec- Suzlon Energy (1QFY18)- A shock, though a positive one. Maintain BUY.pdf',
#  'Westlife Development - Q3FY18 Result Update- JMFL.pdf',
#  'find-information.pdf',
#  '2014-02-05 SUPE.BO (Anand Rathi S) Suprajit Engineering - Growth despite slowdown in the home OEM market%3B Buy.65684159 (2).pdf',
#  'Ambit_Petronet LNG_Company Insight_Whats the plan for cash_20Nov2017.pdf',
#  'Tree_House_Education_BIRI_IPO_Report.pdf',
#  'JM Financial- NTPC - 1Q18 Core RoE at 19%; High commercialisation cycle begins.pdf',
#  'JSW-20170123-MOSL-RU-PG006.pdf',
#  'Coromandel Conference_Call_106395_20160727.pdf',
#  'TMKN 2QFY18 Outlook Review.pdf',
#  "India Banks Undoing Financial Repression Structural Reset of Economics 3-Sep'14.pdf",
#  'ECO-RBI_POLICY-20180604-MOSL-ES-PG006.pdf',
#  'IGL.pdf',
#  'Jefferies- India Banks Group Pricing of Credit 101.pdf',
#  '5April 2018_India_Daily.pdf',
#  'AMP - 180403.pdf',
#  'BOAML-StagnatingIndicators.pdf',
#  'TIl Q1 2015 reults.pdf',
#  'Adani_Power_Q1FY18_results.pdf',
#  '1345798948346-a (2).pdf',
#  'Full Report of Future of Mobile Value Added Services (VAS) in India.pdf',
#  'IndusInd_Bank_-_4QFY18_-_HDFC_sec.pdf',
#  'Avant Garde Wealth Mgmt - Quarterly letter - 1309.pdf',
#  'the economic times - gfl - wind turbines - amdavad - 27102007.pdf',
#  'India_Opportunities_Real_Estate_Fund_March12.pdf',
#  'Equirus_Securities_PGHH_Update_Note_15.03.2016.pdf',
#  'Summary.pdf',
#  '[Kotak] Havells India (Rs260,ADD)-eRrgrp- Sylvania disappoints.pdf',
#  'INFOE-20141119-MOSL-CU-PG006.pdf',
#  'Ashiana Housing - Concall -  Feb2010.pdf',
#  'Defence.pdf',
#  'mss2.pdf',
#  '[Kotak] Marico, May 3, 2018.pdf',
#  'banking_profitability.pdf',
#  'India Strategy - Non-linear winners.pdf',
#  'coal india kotak may2017.pdf',
#  'Avendus- Housing Financials Concerns on competition are overdone.pdf',
#  'mayur2.pdf',
#  'DepositBasedMem.pdf',
#  'Enam_Q3_FY11.pdf',
#  'KPIT-20170427-MOSL-RU-PG012.pdf',
#  'CRISIL-Research_ier-report-infinite-2014.pdf',
#  'Indsec- The Byke Hospitality Ltd -errclub- Q3FY17-Conference and Result Update.pdf',
#  'India-Maize-2014_v2.pdf',
#  'g32n06a.pdf',
#  'Tiles Sectors Thematic Note.pdf',
#  'Award2007_Winners.pdf',
#  'collateral_management.pdf',
#  "TITAN - Inside India's Most Successful Consumer Brand.pdf",
#  'Alchemy_Class_J_September2012.pdf',
#  'Manappuram General Finance  - Conference Call Transcript 21st-Jan-10-EDEL.pdf',
#  'Ambit.pdf',
#  'CLSA - Greed & Fear (Jokowi update) - 21082014.pdf',
#  'Atul-Tgt714.pdf',
#  'BP Equities- National Buildings Construction Corporation Ltd NBCC- Short note_11th April, 2014.pdf',
#  'mt2.6p7.pdf',
#  '160125_Huchems_Final (2).pdf',
#  'Cholamandalam Investment Q1FY16 Result Update.pdf',
#  'FEMANotif_form.pdf',
#  'Consolidated Financials Results_Q3FY17.pdf',
#  'VRL Logistics 2QFY19 result update - 181105.pdf',
#  'CEMENT_-_SECTOR_UPDATE-JUL-16-EDEL1.pdf',
#  'MEDIA_-_SECTOR_UPDATE-FEB-16-EDEL.pdf',
#  'Conviction Ideas  NDTV.pdf',
#  'MindTree_Update_Jun17.pdf',
#  'Mergers_and_Acquisitions_Basics_-_The_Key_Steps_of_Acquisitions,_Divestitures,_and_Investments.pdf',
#  'AGROTECH+-+PC.pdf',
#  'EDEL- Top Picks – Must Stocks in the portfolio.pdf',
#  'Charter_International.pdf',
#  'IDirect_Banking_SectorReport_Mar15.pdf',
#  'JMN%20Credit%20analyst.pdf',
#  'DWSN_AR07.pdf',
#  'ECO-USD-20180618-MOSL-ES-PG006.pdf',
#  'CRG-20140903-MOSL-CU-PG014.pdf',
#  'data_7.pdf',
#  'Time+Technoplast+Ltd_IER_QuarterlyUpdate.pdf',
#  'Exide_2QFY16 Results Review.pdf',
#  'Ascension-Industries-Modular-Design.pdf',
#  'HINDALCO_INDUSTRIES_-_COMPANY_UPDATE-JUN-16-EDEL.pdf',
#  'Digital Consumers.pdf',
#  'ITC-20170127-MOSL-RU-PG010.pdf',
#  'economy - india - 261114 - nomura.pdf',
#  'GC14-4907_2.pdf',
#  'Family Office Network by Mark Drucker.pdf',
#  'Ambit_Alpha This Week_04Dec2017.pdf',
#  'Majesco_-_2QFY18_-_HDFC_sec.pdf',
#  'funding-strategies.pdf',
#  'EIL Annual PPT - FY 13-14 - May 2014 - Rev 2 - Final1.pdf',
#  'BEML Ltd.pdf',
#  'eq_HAVELLS_upd9_10Jun2013.pdf',
#  'IWL- Consolidated -Published Results Format-30062014.pdf',
#  'BoAML on Cummins.pdf',
#  'LAURUS-20180511-MOSL-RU-PG008.pdf',
#  'Bajaj Finance Ltd - 1QFY19 RU - Quantum Sec (2).pdf',
#  'HSBC- Havells India Limited (HAVL IN) -eRrgrp-  Initiate at OW Lighting up the way.pdf',
#  'INFO-20141205-MOSL-CU-PG010.pdf',
#  'Enam  - India Strategy - A Presentat.pdf',
#  'FCSA_Acc_report.pdf',
#  'ALSTOM India Ltd.pdf',
#  'India_Strategy_Rural_Safari_April18.pdf',
#  'HDFC_20180109_0000.pdf',
#  'CEM-20160202-MOSL-SU-PG006.pdf',
#  'Indo Count Industries Ltd.pdf',
#  'Angel Broking - Ujjivan Financial Services Ltd. - IPO Note (SUBSCRIBE).pdf',
#  'theindiandefensemarket-istherespacefornorthamericancompanies-110202185211-phpapp02.pdf',
#  '20141016_Kitex-Garments-Limited_204_QuarterUpdate (2).pdf',
#  'McKinsey- Digitizing oil and gas production.pdf',
#  'ITDC_detail.pdf',
#  '[Kotak] Technology, November 21, 2017.pdf',
#  'Ambit- Thematic- Strategy - Banking sector report card.pdf',
#  'AMP - 131122.pdf',
#  'Aviation_sector_IC_June16.pdf',
#  'ds_value_28sep04.pdf',
#  'GIC Housing Finance - Company Update - Centrum 20022014.pdf.qk6z28q.pdf',
#  'HSBC- India Fertilizer - Takeaways from our meeting with key fertilizer participants.pdf',
#  'Andrew Yule AR 2015 Annotated.pdf',
#  'mcx_123.pdf',
#  'UBS strategt 2016.pdf',
#  'Citi- Cadila Healthcare (CADI.BO) - Successful Moraiya Inspection- A Key Bottleneck Lifted, Focus Shifts to Execution.pdf',
#  'UBS Daily - 31 March 2014 (India Consumer- Godrej Consumer- United Spirits- Hindustan Unilever- Titan- ITC).pdf',
#  'GMO_QtlyLetter_2Q14.pdf',
#  'Finolex Cables Ltd - AGM points _28-06-13_.pdf',
#  'annual_report2013.pdf',
#  'Kwality_Q2 & H1 FY18 Results Table.pdf',
#  'EMConsumer-PineBridge.pdf',
#  'IncaseyoumisseditNA161216xe261733.pdf',
#  'Havells India Q1FY13 Result Update.pdf',
#  'Maize and Sugarcane GM crops and markets in Selected African Countries_2014.pdf',
#  'Ashok_Leyland_-_2QFY18_-_HDFC_sec.pdf',
#  'Cipla_Q1FY18_results.pdf',
#  'ALPM-20160729-MOSL-RU-PG010.pdf',
#  'Building Materials - Crude and USDINR double whammy.pdf',
#  'ITC JMFIN.pdf',
#  'MEGH-CR-280416 - Final.pdf',
#  'IGL-20170811-MOSL-RU-PG008.pdf',
#  'EY-india-cost-of-capital-a-survey.pdf',
#  'CYL-RR-210417.pdf',
#  'CLSA - Greed & Fear (Subsidy focus)-25092014.pdf',
#  'Cheap+Coal+Does+Not+Benefit+The+Indian+People.pdf',
#  'Cadila_Q2FY17_Result.pdf',
#  'MEDIA_-_Q1FY16_RESULT_PREVIEW-JUL-15-EDEL.pdf',
#  'HDFC sec- Cyient (4QFY17)-errclub- Good show, priced in. Maintain NEUTRAL.pdf',
#  'IoT_IBSG_0411FINAL.pdf',
#  'EF-City Union Bank.pdf',
#  'BPCL BofA ML.pdf',
#  'Conference_Call_102355_20120807[1].pdf',
#  'Kotak Strategy_Foreign fund-flow tracker January 06 2016.pdf',
#  'TMX-20170809-MOSL-RU-PG012.pdf',
#  'Global Economic Outlook 2014_Dec 2013.pdf',
#  'KNR Constructions Ltd Q1FY17 Result Update_BUY.pdf',
#  'BJAUT-20150527-MOSL-DR-PG026.pdf',
#  'IDFC_-_COMPANY_UPDATE-SEP-14-EDEL.pdf',
#  'Ambit Results Insights_19Jan2018.pdf',
#  '20141020_Kewal-Kiran-Clothing-Ltd_IER_FirstCut_INE401H01017.pdf',
#  'D1CB4357_3750_41CF_BEE2_3E721A43C4A6_115002.pdf',
#  'CEAT_Investor Presentation_Q2FY14.pdf',
#  'measuringmedia.pdf',
#  'The End of Fair Trade Brochure FINAL.pdf',
#  'BESI_MAX_IN_20150128.pdf',
#  'APM_Industries-Buy_Report-220113.pdf',
#  'AF_Animals_Milk_Dairy_Intro.pdf',
#  'JM Financial - PI Industries Ltd. - Order Book Growth Continues.pdf',
#  'IDR_ONMB_050812_10112.pdf',
#  'COROMANDEL - PL.pdf',
#  'HDFC_Life_Annual_Report_10-11.pdf',
#  'VCPEFall2005syllabus.pdf',
#  'AUTO-SALES-20140929-MOSL-SU-PG004.pdf',
#  'Memorandum_Articles.pdf',
#  'FCH_AR_FINAL-2010-11.pdf',
#  'June 2012 Presentation.pdf',
#  'winter20071.pdf',
#  'Transcript of the Q1 2018-19 Earnings Conference Call held at 19 00 hrs IST on July 10, 2018 (1).pdf',
#  'Dynamatic+Technologi...R_QuarterlyUpdateFirstCut.pdf',
#  '[Kotak] Infrastructure, September 1, 2016.pdf',
#  'Deutsche Bank- Indraprastha Gas Alert -Visibility for growth remains weak beyond FY17, maintain Hold.pdf',
#  'Bharti Infratel Buyback.pdf',
#  'Castrol+India+-+4QCY11+B&K.pdf',
#  'Cadila Healthcare_Company update_Nov 29, 2017.pdf',
#  'urban_realestate.pdf',
#  'Varun Beverages- JM Financial.pdf',
#  'TTMYGH_02_Dec_2013.pdf',
#  'NBFC _ CS.pdf',
#  'infrastructure-publications-case-notes-city-natural-gas-distribution.pdf',
#  'IDirect_NHPC_Q4FY17.pdf',
#  'UPL - 1QFY19 RU - JM Financial.pdf',
#  '2007.10.02 NHR COA merger investor presentation.pdf',
#  'INDIGO-20171124-MOSL-CU-PG016.pdf',
#  'TTMT-20141016-MOSL-PG004.pdf',
#  'Finolex Q3FY19-Presentation.pdf',
#  'ENGG-INVESTMENT-20150223-MOSL-FC-PG022.pdf',
#  'ICICI-Securities-Housing-Finance-Companies-Firm-Foundation.pdf',
#  'AGIC 2014-10TH-POST CONFERENCE-MOSL-PG130.pdf',
#  'KKC-20160805-MOSL-RU-PG010.pdf',
#  'Torrent_Pharma_-_3QFY17-_HDFC_sec.pdf',
#  'City Union Bank - Initiating Coverage.pdf',
#  'TIL_Annual_Report2012-13.pdf',
#  'Thyrocare_Initiation_25April2017.pdf',
#  'INL-SI-120716.pdf',
#  'TEST FOR ECHO EDITEDV2.pdf',
#  'IDirect_VSTTillers_Q1FY18.pdf',
#  'coal india MOSL 02052017.pdf',
#  'KULKARNI.pdf',
#  'Kotak India-19June 2018_India_Daily.pdf',
#  'ICICI Pru Life - BAML.pdf',
#  'Untitled attachment 00160.pdf',
#  'Jyothy Most.pdf',
#  'Cautious-and-choosy-Quality-to-the-fore.pdf',
#  'India Steel UBS.pdf',
#  'investment_strategy3.pdf',
#  'ar_jyothy.pdf',
#  'tubeinstallation_tools.pdf',
#  'Double_shift_secondary_schools_En01.pdf',
#  'AnchorErngGrwth_25112015.pdf',
#  'CLSA G & F 2015.pdf',
#  'BHFC-20171108-MOSL-RU-PG010.pdf',
#  'How To Make Prudent Investments For Your Organization.pdf',
#  '5328910312.pdf',
#  'Real_Estate_-_4QFY17_Results_Preview_-_HDFC_sec.pdf',
#  'AGM 07 to 08.pdf',
#  'Deloitte  -  The Untold Story Of America’s Debt.pdf',
#  'analysts_meet May_2_2014.pdf',
#  'Satellic.pdf',
#  'HDFC-TTK PRESTIGE-CLSA.pdf',
#  'HDFC Sec-eRr Reports-D B Corp-Buy-Add on Dips to band-Target 460-500-Time Horizon-1 Year.pdf',
#  'IIB - EDEL pdf.pdf',
#  'AMSC_News_2015_12_17_Financial.pdf',
#  'Macquarie- Fortis Healthcare (Outperform) - SRL demerged – to unlock value.pdf',
#  'DRRD-20150520-MOSL-CU-PG010.pdf',
#  'Va Tech Wabag India Ltd Q2FY16 Result Update.pdf',
#  'The Paper Products Ltd - 3QCY12 - Result Update - 021112.pdf',
#  'BofA ML- Industrials - India - Q1FY17 preview - Order flows  profits looking up  execution challenges to persist.pdf',
#  '[Kotak] Nestle India, October 26, 2018.pdf',
#  'ICNT-20170214-MOSL-RU-PG010.pdf',
#  'Ambit Insights_30Nov2017.pdf',
#  'Lovable Annual Report 2013.pdf',
#  'Dr_Reddys_Labs_-_Update_-_Dec17_-_HDFC_sec.pdf',
#  'table-2.pdf',
#  'EDEL- NBCC -errclub- Sanguine outlook.pdf',
#  '[Kotak] Consumer Products (Cautious) Month in review - July 2017- GST-led price cuts underway.pdf',
#  'Wipro - 1QFY19 RU - MOSt.pdf',
#  'BULLS & BEARS - India Valuations Handbook - 20151103-MOSL.pdf',
#  'IDirect_InoxLeisure_Q1FY18.pdf',
#  'Cement Initiation Report.pdf',
#  'IDirect_eClerx_Q1FY18.pdf',
#  'ASHP_shortage_guide09.pdf',
#  '1FinancialsStatement_RFacility_FY2015-16.pdf',
#  'Ashiana 2011-2012_Annual_Report.pdf',
#  'LIC_Housing_Finance_-_4QFY18_-_HDFC_Sec.pdf',
#  'Greed and Fear - Shifting consensus.pdf',
#  'Apna Supply Chain Weekly_Milind Shahane_05.02.15.pdf',
#  'Ultratech Cement Ltd - Geojit BNP Paribas.pdf',
#  'Dec13_Economics of Financial Inclusion.pdf',
#  'Jubiliant+Foodworks.pdf',
#  'IBA_PF_presentation_270407.pdf',
#  'ShowNews.pdf',
#  'BNK_051616_25242.pdf',
#  'Mahindra and Mahindra Financial Services-result update-Jul-13-EDEL.pdf',
#  'Vinyl India 2018  - Brochure_19 March 2018.pdf',
#  'India+Infrastructure+Insights.pdf',
#  'Trisara-Signature-Villa_FromADMIN1.pdf',
#  'Indo-Count-CD.pdf',
#  'ECO-MONSOON-20140816-MOSL-ES-PG002.pdf',
#  'EDELFLASH_-_SUN_PHARMA_-_IMPORT_ALERT_-_13-MAR-14.pdf',
#  'Astral Poly Technik - EIf.pdf',
#  'Bharat+Electronics+-+Visit+Update+-+Sep+13.pdf',
#  'indiainfo.pdf',
#  'banks_db_191011.pdf',
#  'HDFCB-RR-260417.pdf',
#  'Deutsche Bank- Motherson Sumi Systems-eRrgrp- NDR takeaways – focus on technology will drive business growth.pdf',
#  'BNK_090215_195059.pdf',
#  'Corporate%20Governance.pdf',
#  'Affordable_Housing_in_India_2012.pdf',
#  'Union Bank of India - 1QFY18 Earnings Report - Aug 17.pdf',
#  'IndusInd BankQ3FY14 RU.pdf',
#  'IBU_May03.pdf',
#  'Havells Unaudited Financial Results Q3FY14.pdf',
#  'Exide_4QFY16 Results Review Final.pdf',
#  'dp28245.pdf',
#  'Ambit Results Insights_22Jan2018.pdf',
#  'EDELWEISS_FUND_INSIGHT_JAN-14-EDEL.pdf',
#  '0810ifrsrealestate.pdf',
#  'Earnings-Presentation-Q3-2013-14.pdf',
#  'AMP - 180416.pdf',
#  'IDFC Securities- Sector update- Indian Financials - An On-ground Guide to Financial inclusion.pdf',
#  'Dissertation_RamkumarK.pdf',
#  'ICICI Direct- Result Update - India Cement (Buy) errclub Decline in power & fuel cost drives margins....pdf',
#  'TTMT-20181009-MOSL-CU-PG006.pdf',
#  '07102014115602MMDR Act 1957_10052012 (2).pdf',
#  'Aarti concall transcript dec 2016.pdf',
#  'Embracing Innovation Driving Growth Across Healthcare Continuum_Medcon_2017.pdf',
#  'Britannia_CallUpdate_050115.pdf',
#  'Bits---pieces-5-Feb-2010---Golden-Tiger.pdf',
#  'brent wti crude wxplained.pdf',
#  'BHEL-20150303-MOSL-CU-PG018.pdf',
#  'Indian Gas Sector - Citi .pdf',
#  'DELTA-20140918-MOSL-SL-PG032.pdf',
#  'GlobalDirectory.pdf',
#  'WHat+i+learned+-+Ridham+I+-+180612+-+Morgan.pdf',
#  'Pocket-Guide-for-Digital-Payments.pdf',
#  'KPMG-Flash-News-JSW-Energy-Limited.pdf',
#  'India Cement note UBS Q1 2017.pdf',
#  'IT services UBS.pdf',
#  'petronet.pdf',
#  'TTKPT-RR-170113.pdf',
#  'Textile Axis report.pdf',
#  'expertprint.pdf',
#  'Va Tech Wabag - 3QFY18 Result Update- PL India.pdf',
#  '[Kotak] Godrej Properties, January 29, 2019.pdf',
#  'Kewal Kiran Analsyt Ppt Q4  FY2011.pdf',
#  'India+Banks+-+Discom+Restructuring+140312.pdf',
#  'UTCEM-20180425-MOSL-RU-PG008.pdf',
#  'MAGMBFeb11.pdf',
#  'make-consolidated-january19-2013-to-march31-2014.pdf',
#  'Balkrishna Industries. - Revenue recovery and cost advantage make a good combination.pdf',
#  '2003_Issue1.pdf',
#  'Escorts Ltd -Quarter ending March 2014 - Result Update - Accumulate.pdf',
#  'CompanyValuationPPT.pdf',
#  'conf axis nov13.pdf',
#  'Indian Road Sector_ASBL & ITNL Initiation_Sept 1 2014.pdf',
#  'document-807204990.pdf',
#  'Corporate Presentation - January 2015.pdf',
#  'ICICI Prudential Life Insurance (ICIR.NS)- Correction- 10 Focus Charts – MS.pdf',
#  'time-rhpfinal.pdf',
#  'Vodafone Idea (VODA.BO) - 2QFY19 results - Citi.pdf',
#  'Advancing-Financial-Inclusion-in-India.pdf',
#  'LICHF_310314.pdf',
#  'MANDHANA INDUSTRIES LIMITED-06-10-2016.pdf',
#  'dip2.pdf',
#  'avanthapower.pdf',
#  'JSW Steel Q4FY17 - Result Update - Axis Direct - 25052017_25-05-2017_11.pdf',
#  'Tourism Finance Corp - Stock Note - 120118.pdf',
#  'iifl - strategy - 2014 outlook - 20140102_08_57_04.pdf',
#  '[Kotak] Karur Vysya Bank, July 25, 2018.pdf',
#  'MACA-20150212-MOSL-SLU-PG010.pdf',
#  'INFOSYS - ANTIQUE.pdf',
#  'Elgi Equipments_IC_Spark Capital_23.03.2015.pdf',
#  'ChinaSec_24May06.pdf',
#  'United Breweries Q4FY18 Result Update - Emkay.pdf',
#  'Banswara Syntex Ltd.-Results.pdf',
#  'Gujarat_Fluorochemicals_Ltd_100315.pdf',
#  "JM Financial - Textiles Sector - Cotton Sheet US Market Share Dips In May'16 (Sector Update).pdf",
#  'HDFC Securities 16-May-16.pdf',
#  'HDFC+Warrants.pdf',
#  'BATINDIA_20130729.pdf',
#  'FIEM Industries - IC - Centrum - 27.03.14.pdf',
#  'ANewParadigmforManagingforShareholderValue.pdf',
#  'TEL-20180108-MOSL-SU-PG006.pdf',
#  'Titan - SELL - CLSA.pdf',
#  'BHEL-2QFY16 Review.pdf',
#  'ARVND-20150806-MOSL-RU-PG014.pdf']

# %% [markdown]
# ## Essential utility functions to process pdf data

# %%
def save_obj(fname, obj):
    with open(fname, 'wb') as handle:
        dill.dump(obj, handle)

def load_obj(fname):
    with open(fname, 'rb') as handle:
        obj = dill.load(handle)
        return obj

# %%
def process_pdfminer(file_list):  ## function to parse pdf data using pdfminer text mining package
    
    r=0
    text_corpus = {}

    for file in file_list:
        print(f'Reading : {file} \n')
        pdf_text = phl.extract_text(source_path+file)
        pdf_text = pdf_text.split('\n')
        pt = [i for i in pdf_text if len(i)>1]

        text_corpus[file] = pt
        r = r + 1

    print(f'Total files read : {r}/{len(file_list)}')
    
    save_obj('./corpus_pdfminer.pkl', text_corpus)

def process_pdfocr_and_pdf2text(file_list):  ## function to pdf data using pdf2text and ocr utility of textract
    
    pdf2text_corpus = {}
    tf = len(file_list)
    f = 1
    for file in file_list:
        try:
            print(f'PDFtoText reading ({f}/{tf}): {file}')
            text = textract.process(source_path+file, method='pdftotext', language='eng', input_encoding=None, output_encoding='utf8')
            text = str(text).replace('\\x','')
            texts = str(text).replace('\\n','')
            texts = texts.split('.')
            texts = [x for x in texts if len(x)>1]
            pdf2text_corpus[file] = texts
            f = f + 1
        except:
            continue

    save_obj('pdftotext_corpus.pkl', pdf2text_corpus)

    ocr_corpus = {}
    for file in file_list:
        print("OCR reading : ",file)
        ## each pdf page is turned to image and ocr perfomed on each image using pytesseract
        text = textract.process(source_path+file, method='tesseract', language='eng')  
        text = str(text).replace('\\x','')
        texts = str(text).split('\\n')
        texts = [x for x in texts if len(x)>1]
        ocr_corpus[file] = texts

    save_obj('ocr_tesseract_corpus.pkl', ocr_corpus)

# %%
## function to find BSE listed company names and symbols

def process_bse_companies():
    
    bse = pd.read_csv('./bse_companies.csv', encoding='latin-1')
    print(bse.head())

    nse_symbols = list(bse['CD_NSE Symbol'])
    bb_symbols = list(bse['CD_Bloomberg Code'])
    com_names = list(bse['Company Name'])

    nse_symbols = [x for x in nse_symbols if str(x)!='nan']
    bb_symbols = [x for x in bb_symbols if str(x)!='nan']
    
    com_names = [x for x in com_names if str(x)!='nan']
    # print(nse_symbols, bb_symbols)

    all_symbols = [*nse_symbols, *bb_symbols]

    company_symbols = set()

    for sym in all_symbols:
        company_symbols.add(sym)

    save_obj('company_symbols.pkl', company_symbols)
    save_obj('company_names.pkl', com_names)
    
def get_bse_companies():
    return load_obj('company_symbols.pkl')

# %%
## function to store author names found in the metadata of each pdf file

def get_authors(file_list):
    
    r=0
    metadata_corpus = {}

    for file in file_list:
        print(f'\n Reading : {file} \n')
        fp = open(source_path+file, 'rb')
        parser = PDFParser(fp)
        doc = PDFDocument(parser)
        #print("\n",doc.info[0].keys())
        try:
            if('Author' in doc.info[0].keys()):
                print(doc.info[0]['Author'])
                metadata_corpus[file] = doc.info[0]['Author']
                r = r + 1
        except:
            print("skipped")

    print(f'Total files metadata read : {r}/{len(file_list)}')
    save_obj('author_corpus_pdfminer.pkl', metadata_corpus)

# %% [markdown]
# ## Loading artificats pre-processed from pdf files

# %%
text_corpus = load_obj('./corpus_pdfminer.pkl')
#pdftotext_corpus = load_obj('./pdftotext_corpus.pkl')
ocr_corpus = load_obj('ocr_tesseract_corpus.pkl')
company_symbols = list(load_obj('company_symbols.pkl'))
company_names = list(load_obj('company_names.pkl'))
author_info = load_obj('./author_corpus_pdfminer.pkl')

# %% [markdown]
# ## Functions to process email id and extract authors / institutions

# %%
def find_email(texts):  ## function to find email ids in the extracted text
    emails_found = set()
    for i in range(len(texts)):
        if(bool(validate_email(texts[i]))):  ## using validate_email package to find valid email id
            emails_found.add(texts[i].strip())
    
    if(len(emails_found)==0):  ## otherwise, using @ based string processing to identify email id
        for t in texts:
            if(t.find('@')>0):
                parts = t.split(' ')
                for p in parts:
                    if '@' in p:
                        emails_found.add(p.strip())
                        
    return list(emails_found)

def find_companies(texts):  ## function to find company symbols/names by comparing with BSE listed comapnies
    #print(company_symbols)
    companies_found = set()
    company_names_found = set()
    for i in range(len(texts)):
        for j in range(len(company_symbols)):
            if(texts[i].startswith(company_symbols[j])):
                companies_found.add(company_symbols[j])
        for k in range(len(company_names)):
            if(texts[i].startswith(company_names[k])):
                company_names_found.add(company_names[k])
                
    companies_found = list(companies_found)
    companies_found = [x for x in companies_found if x!=' ']
    companies_found = [x for x in companies_found if x!='BSE']
    
    company_names_found = list(company_names_found)
    company_names_found = [x for x in company_names_found if x!=' ']
    company_names_found = [x for x in company_names_found if x!='Net Current Asset']
    
    return companies_found, company_names_found

# %%
def split_emails(emails):  ## function to split email to find author and source organisations
    if emails:
        names = set()
        orgs = list()
        for i in range(len(emails)):
            eid = emails[i]
            esplit = eid.split('@')
            #print(esplit)
            if(len(esplit[0])>2):
                if(esplit[0][0]=='('):
                    nm = esplit[0][1:]
                else:
                    nm = esplit[0]
                names.add(nm)
            else:
                continue
            orgsplit = esplit[1].split('.')
            orgs.append(orgsplit[0])

        names = list(names)
        #print(orgs)
        if(orgs):
            main_org = Counter(orgs).most_common(1)[0][0]
        else:
            main_org = None
            
        return names, main_org, list(set(orgs))

# %%
def get_frequent_source(texts):  ## function to find source organisation from extracted text
    
    doc_owner = []
    for i in range(len(texts)):
        if(texts[i].startswith('Source') or texts[i].startswith('Company') or texts[i].startswith('Source Company')):
            #print(texts[i])
            doc_owner.append(texts[i])
    if(doc_owner):
        main_doc_owner = Counter(doc_owner).most_common(1)[0][0]
        #print(main_doc_owner)
        if(main_doc_owner.find(':')):
            mdo = main_doc_owner.split(':')[1]
        if(mdo.find(',')>=0):
            mdo = mdo.split(',')[1]
        return mdo.strip()

# %% [markdown]
# ## Functions to extract trade calls and target prices

# %%
def extract_price(st):
    
    prices = []
    main_price = None
    
    for sent in st:
        
        #print(sent)
        p = ''
        if(sent.find('TP')>=0):
            sent = sent.split('TP')[1]
            
        if(sent.find('INR')>=0):
            a = sent.split('INR')
            p = a[1].split(' ')[0]
            if(p.isdigit()):
                prices.append(p)
        if(sent.find('Rs. ')>=0):
            a = sent.split('Rs. ')
            p = a[1].split(' ')[0]
            if(p.isdigit()):
                prices.append(p)
        if(sent.find('Rs')>=0):
            #print(sent)
            a = sent.split('Rs')
            p = a[1].split(' ')[0]
            if(p.isdigit()):
                prices.append(p)
        if(p==''):
            for i in sent.split(' '):
                if(i.isdigit()):
                    prices.append(i)
    
    #print(calls, prices)
    if(prices):
        main_price = Counter(prices).most_common(1)[0][0]
        return float(main_price)
    
    return main_price

def extract_call_price(pt):
    
    #print(pt)
    calls = []
    prices = []
    main_call, main_price = None, None
    
    for tup in pt:
        
        call = tup[0]
        calls.append(call)
        sent = tup[1]
        p = ''
        
        if(sent.find('TP')>=0):
            sent = sent.split('TP')[1]
            
        if(sent.find('INR')>=0):
            a = sent.split('INR')
            p = a[1].split(' ')[0]
            if(p.isdigit()):
                prices.append(p)
        if(sent.find('Rs. ')>=0):
            a = sent.split('Rs. ')
            p = a[1].split(' ')[0]
            if(p.isdigit()):
                prices.append(p)
        if(sent.find('Rs')>=0):
            #print(sent)
            a = sent.split('Rs')
            p = a[1].split(' ')[0]
            if(p.isdigit()):
                prices.append(p)
        if(p==''):
            for i in sent.split(' '):
                if(i.isdigit()):
                    prices.append(i)
            for i in sent.split(':'):
                if(i.isdigit()):
                    prices.append(i)
    
    #print(calls, prices)
    if(calls and prices):
        main_call = Counter(calls).most_common(1)[0][0]
        main_price = Counter(prices).most_common(1)[0][0]
        return main_call, float(main_price)
    
    return main_call, main_price

def get_trade_call(texts):
    
    main_call, main_price = None, None
    calls = []
    only_calls = []
    primary_targets = []
    secondary_targets = []
    prime_call = None
    
    for i in range(len(texts)):
        
        if(('Buy' in texts[i].strip()) or ('buy' in texts[i].strip())):
            calls.append((texts[i],'Buy'))
            
        if(('Sell' in texts[i].strip()) or ('sell' in texts[i].strip())):
            calls.append((texts[i],'Sell'))
            
        if((('Target' in texts[i].strip() or 'target' in texts[i].strip()) or ('Price' in texts[i].strip() or 'price' in texts[i].strip())) or ('TP' in texts[i].strip())):
            secondary_targets.append(texts[i])
            
        if('Rating' in texts[i].strip() or 'rating' in texts[i].strip()):
            if('Buy' in texts[i].strip() or 'buy' in texts[i].strip()):
                prime_call = 'Buy'
            if('Sell' in texts[i].strip() or 'sell' in texts[i].strip()):
                prime_call = 'Sell'
            #print("\nPrime Call : ",prime_call)
            
    #print(calls)
    
    if(calls):
        for c in calls:
            if(c[0].find('target')>=0 and c[0].find('price')>=0):
                primary_targets.append((c[1], c[0]))
            else:
                if(c[0].find('target')>=0 or c[0].find('TP')>=0):
                    secondary_targets.append(c[1])
                    
            only_calls.append(c[1])
            
    
    #print("Primary targets : \n", primary_targets)
    #print("Secondary targets : \n", secondary_targets)
    
    if(primary_targets):
        main_call, main_price = extract_call_price(primary_targets)
        if(prime_call):
            main_call = prime_call
        return main_call, main_price

    if(secondary_targets):
        main_price = extract_price(secondary_targets)
    
    if(only_calls):
        main_call = Counter(only_calls).most_common(1)[0][0]
        
    if(prime_call):
        main_call = prime_call
    
    if(main_call and main_price):
        return main_call, main_price
    else: 
        return None, None

# %% [markdown]
# ## Final Loop to create output csv

# %%
df = pd.DataFrame(columns = ['file', 'source company', 'authors', 'company symbols', 'company names', 'trade call', 'target price', 'possible sources'])
df = df.astype('object')

# %%
f_num = 1
for f in file_list:
    
    print(f, f"  -  ({f_num}/{len(file_list)})")
    
    ocr_texts = ocr_corpus[f]
    miner_texts = text_corpus[f]
        
    ocr_texts = [x.replace('\xa0', ' ') for x in ocr_texts]
    miner_texts = [x.replace('\xa0', ' ') for x in miner_texts]
    
    emails = find_email(miner_texts)
    if(len(emails)==0):
        emails = find_email(ocr_texts)
        
    comps, comp_names = find_companies(miner_texts)
    if(len(comps)==0):
        comps, comp_names = find_companies(ocr_texts)
        
    try:
        met_auth = author_info[f].decode('utf-8')
    except:
        met_auth = None
        
    #print(emails, comps, met_auth)

    persons, sources, possible_sources = [], [], []
    try:
        persons, sources, possible_sources = split_emails(emails)
    except TypeError:
        persons, sources = [], []

    try:
        frequent_source = get_frequent_source(miner_texts)
    except:
        frequent_source = None
    #print(possible_sources)

    if(frequent_source):
        all_sources = [*possible_sources, frequent_source]
    else:
        all_sources = possible_sources

    #print("\n", persons, sources, all_sources)
    #print("\n", comps)
    
    #finalizing authors by filtering out all possible options
    doc_authors = []
    if(persons):
        doc_authors = persons
    if((met_auth and len(doc_authors)==0)):
        doc_authors.append(met_auth)
    if(len(doc_authors)>6):
        doc_authors = []
        doc_authors.append(met_auth)
    if(len(doc_authors)==0):
        doc_authors = []
        doc_authors.append('NA')

        
    # finalizing authoring institution by filtering out all possible options
    source_companies = []
    if(sources and frequent_source):
        if(sources in frequent_source):
            source_companies.append(frequent_source)
    if(sources and len(source_companies)==0):
        source_companies.append(sources)
    if(frequent_source and len(source_companies)==0):
        source_companies.append(frequent_source)
    if(len(source_companies)==0):
        source_companies.append('Others')

    print("\n",source_companies, "\n", doc_authors, "\n", comps, "\n", comp_names,"\n")
    
    # get possible trade calls and target price
    mc, mp = get_trade_call(ocr_texts) 
    if(mp==None):
        _, mp = get_trade_call(miner_texts)
        
    print(f"Call : {mc}  -  Price : {mp}\n")
    
    # append row to dataframe
    current_col = [f, source_companies, doc_authors, comps, comp_names, mc, mp, all_sources]
    df.loc[len(df)] = current_col
    
    #print(df.tail(1))
    
    f_num = f_num + 1
# Out:
# JPM_022014_14225.pdf   -  (1/590)
#
#  ['jpmorgan']
#  ['deepika.mundra', 'sumit.x.kishore', 'boris.cw.kan']
#  ['BHEL', 'KEC', 'ABB']
#  ['Apar Industries Ltd.', 'Triveni Turbine Ltd.', 'Bilpower Ltd.', 'Finolex Cables Ltd.', 'Voltamp Transformers Ltd.', 'Suzlon Energy Ltd.', 'Siemens Ltd.', 'Diamond Power Infrastructure Ltd.', 'Schneider Electric Infrastructure Ltd.', 'Universal Cables Ltd.']
#
# Call : Sell  -  Price : 20.0
#
# Deep Industries Ltd - Award of Hiring of Integrated Drilling & Completion Services.pdf   -  (2/590)
#
#  ['deepindustrtes']
#  ['info']
#  []
#  []
#
# Call : None  -  Price : None
#
# Industry-Map-of-the-Precious-Metals-Sector.pdf   -  (3/590)
#
#  ['Others']
#  ['john']
#  []
#  []
#
# Call : None  -  Price : None
#
# Ambit India Access_Pre-Budget conference call with Ashok Wadhwa_03Jul2014.pdf   -  (4/590)
#
#  ['ambitcapital']
#  [None]
#  []
#  []
#
# Call : None  -  Price : None
#
# ThinkSoft-Corporate-Presentation-Mar-12.pdf   -  (5/590)
#
#  ['thinksoftglobal']
#  ['dpingle', 'vaidyanathan.n']
#  ['ICICI']
#  []
#
# Call : None  -  Price : None
#
# [Kotak] GlaxoSmithKline Consumer, February 9, 2016.pdf   -  (6/590)
#
#  ['kotak']
#  ['anand.shah', 'kotak.research', 'abhas.gupta', 'rohit.chordia']
#  []
#  []
#
# Call : Buy  -  Price : 12.0
#
# JMFL– TCI EXPRESS -errclub- An Express Delivery Company.pdf   -  (7/590)
#
#  ['jmfl']
#  ['chandragopal.choudhary', 'achal.lohade', 'ruchir.jhunjhunwala', 'sunny.shah', 'jmfinancial.research']
#  ['TCI']
#  []
#
# Call : Buy  -  Price : 405.0
#
# Hotline 93.pdf   -  (8/590)
#
#  ['chta']
#  ['enquiries', 'mail']
#  []
#  []
#
# Call : None  -  Price : None
#
# BHFC_Q1FY17ResultUpdate_7 Aug 16.pdf   -  (9/590)
#
#  ['jmfl']
#  ['shyam.sriram']
#  []
#  []
#
# Call : Buy  -  Price : 7860.0
#
# GST_-_PROPITIOUS_WINDS_OF_CHANGE-DEC-15-EDEL.pdf   -  (10/590)
#
#  ['edelweissfin']
#  ['nilesh.aiya', 'ankit.dangayach', 'nirav.sheth', 'manoj.bahety']
#  ['ACC', 'PVR', 'IRB']
#  []
#
# Call : Sell  -  Price : 250.0
#
# MaricoKayaEnt.pdf   -  (11/590)
#
#  ['motilaloswal']
#  ['info', 'Ravi.Shenoy']
#  []
#  []
#
# Call : Buy  -  Price : 1020.0
#
# business_valuation_methods.pdf   -  (12/590)
#
#  ['Others']
#  ['NA']
#  ['ACC']
#  []
#
# Call : None  -  Price : None
#
# GRUH_Profile_June_2014.pdf   -  (13/590)
#
#  ['Others']
#  ['sn0777']
#  ['LT', 'NH', 'HDFC', 'GRUH']
#  []
#
# Call : Sell  -  Price : 8.0
#
# Copy of 10 LUXE Cost Sheet.pdf   -  (14/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# ICICI Direct- Company Update – Bharat Electronics (Buy) errclub Reiterate.pdf   -  (15/590)
#
#  ['icicisecurities']
#  ['chirag.shah', 'pankaj.pandey', 'sagar.gandhi', 'research']
#  ['ICICI', 'BEL']
#  []
#
# Call : Buy  -  Price : 1560.0
#
# Finolex%20Industries%20Presentation.pdf   -  (16/590)
#
#  ['Others']
#  ['admin']
#  []
#  []
#
# Call : None  -  Price : None
#
# INXW-20170203-MOSL-RU-PG008.pdf   -  (17/590)
#
#  ['motilaloswal']
#  ['Varun.kumar']
#  ['INXW IN']
#  []
#
# Call : Buy  -  Price : 175.0
#
# issue-nov_dec0787[1].pdf   -  (18/590)
#
#  ['skretting']
#  ['arjen.roem', 'zuridah']
#  ['AQUA', 'MIC']
#  []
#
# Call : Sell  -  Price : 2007.0
#
# Timken India Company Update.pdf   -  (19/590)
#
#  ['sparkcapital']
#  ['rseshan', 'mukesh']
#  ['TMKN IN']
#  []
#
# Call : None  -  Price : None
#
# 201390164-Prannoy-Roy-s-email-to-Gurumurthy-regarding-Chidambaram-NDTV-s-Rs-5000-crores-money-laundering-scam.pdf   -  (20/590)
#
#  ['xxxxxxxxxx']
#  ['<xxxx', '<xxxxxxx']
#  ['NDTV']
#  []
#
# Call : None  -  Price : None
#
# GC14-4811_2.pdf   -  (21/590)
#
#  ['PBS.']
#  ['Rosivaldo Novaes']
#  []
#  []
#
# Call : Buy  -  Price : 5.0
#
# V-guard 1QFY17 Review.pdf   -  (22/590)
#
#  [' 26']
#  ['1612']
#  ['VGRD IN', 'TOTAL']
#  []
#
# Call : Buy  -  Price : 22.0
#
# visitor_brou.pdf   -  (23/590)
#
#  ['sitaindia']
#  ['kapilp', 'info', 'bom.mice']
#  ['APEX', 'ABB', 'MDA IN', 'TCS', 'MIC', 'ACE']
#  []
#
# Call : None  -  Price : None
#
# House of debt.pdf   -  (24/590)
#
#  ['credit-suisse']
#  ['ashish.gupta', 'prashant.kumar.3']
#  ['CCCL', 'ICICI', 'PNB', 'DCM', 'GTL', 'IOB', 'SCI', 'IDFC', 'KSK', 'MTNL', 'CESC', 'TTML', 'HDFC', 'NTPC', 'TI', 'SPIC']
#  ['Entegra Ltd.', 'United Spirits Ltd.', 'Sterling Biotech Ltd.', 'Adani Power Ltd.', 'Jet Airways (India) Ltd.', 'Kesoram Industries Ltd.', 'Gammon Infrastructure Projects Ltd.', 'Tata Steel Ltd.', 'Indian Overseas Bank', 'Aurobindo Pharma Ltd.', 'GTL Infrastructure Ltd.', 'Kingfisher Airlines Ltd.', 'Mahanagar Telephone Nigam Ltd.', 'Moser Baer India Ltd.', 'Tata Teleservices (Maharashtra) Ltd.', 'Electrosteel Castings Ltd.', 'Reliance Infrastructure Ltd.', 'Mercator Ltd.', 'Adhunik Metaliks Ltd.', 'United Bank of India', 'Lanco Infratech Ltd.', 'Garden Silk Mills Ltd.', 'Jubilant Life Sciences Ltd.', 'Welspun Corp Ltd.', 'Asahi India Glass Ltd.', 'West Coast Paper Mills Ltd.', 'Tamil Nadu Newsprint & Papers Ltd.', 'Punj Lloyd Ltd.', 'Unitech Ltd.', 'Usha Martin Ltd.', 'Alok Industries Ltd.', 'Electrotherm (India) Ltd.', 'Murli Industries Ltd.', 'Jaiprakash Power Ventures Ltd.', 'Reliance Communications Ltd.', 'State Bank Of India', 'Sakthi Sugars Ltd.', 'Electrosteel Steels Ltd.', 'Tata Communications Ltd.', 'Jaiprakash Associates Ltd.', 'United Breweries (Holdings) Ltd.', 'Ramsarup Industries Ltd.', 'Ankur Drugs & Pharma Ltd.', 'Jain Irrigation Systems Ltd.', 'GTL Ltd.', 'Visa Steel Ltd.', '3I Infotech Ltd.', 'Shree Renuka Sugars Ltd.', 'Punjab National Bank', 'Jindal Stainless Ltd.', 'Suzlon Energy Ltd.', 'Mukand Ltd.']
#
# Call : Sell  -  Price : 690.0
#
# JP+Morgan-+Phoenix+Mills+-+Annuity+income+could+grow+4.pdf   -  (25/590)
#
#  ['jpmorgan']
#  ['gunjan.x.prithyani', 'Quant_Strategy', 'saurabh.s.kumar']
#  []
#  ['Phoenix Mills Ltd.']
#
# Call : Sell  -  Price : 11.0
#
# IWEO_2011_lowres.pdf   -  (26/590)
#
#  ['gwec']
#  ['info', 'wiseinfo', 'secretary']
#  ['GLOBAL', 'ICICI']
#  []
#
# Call : Sell  -  Price : 2020.0
#
# Bajaj Corp 4QFY18 Outlook Review.pdf   -  (27/590)
#
#  ['sparkcapital']
#  ['tejash', 'madhav', 'gnanasundar']
#  ['GNA', 'STAN', 'TOTAL', 'MARG', 'MADHAV']
#  []
#
# Call : Buy  -  Price : 586.0
#
# 2010_analyst_meet_presentation.pdf   -  (28/590)
#
#  ['=2007-08']
#  ['e28094']
#  ['ITC', 'UBL', 'KFA']
#  []
#
# Call : Sell  -  Price : 18.0
#
# DRRD-20170505-MOSL-CU-PG006.pdf   -  (29/590)
#
#  ['motilaloswal']
#  ['Varun.kumar']
#  ['DRRD IN']
#  []
#
# Call : Buy  -  Price : 3050.0
#
# Avant Garde Wealth Mgmt - Quarterly letter - 1306.pdf   -  (30/590)
#
#  ['Capital Line']
#  ['NA']
#  []
#  []
#
# Call : Buy  -  Price : 2013.0
#
# 20141013_IndusInd-Bank-Limited_204_QuarterUpdate.pdf   -  (31/590)
#
#  ['motilaloswal']
#  ['reports', 'Alpesh.Mehta', 'kadambari.balachandran', 'anosh.Koppikar', 'Vallabh.Kulkarni']
#  ['IIB IN', 'IDBI', 'ICICI', 'PNB', 'SBIN', 'IDFC', 'HDFC']
#  []
#
# Call : Buy  -  Price : 685.0
#
# ICRA Sector Updates - Indian Tractor Industry, Aug 2012.pdf   -  (32/590)
#
#  ['icraindia']
#  ['aghosh', 'subrata', 'shishir.kumar', 'd.vinod']
#  ['ICRA', 'BANG']
#  []
#
# Call : None  -  Price : None
#
# ECO-CPI-IIP-20180612-MOSL-ES-PG006.pdf   -  (33/590)
#
#  ['motilaloswal']
#  ['Nikhil.Gupta', 'Rahul.Agrawal']
#  []
#  []
#
# Call : None  -  Price : None
#
# HFC-23_Policy-Briefing1.pdf   -  (34/590)
#
#  ['cdm-watch']
#  ['fionnualawalravens', 'Eva.filzmoser']
#  ['GLOBAL']
#  []
#
# Call : Sell  -  Price : 2009.0
#
# Ultratech Cement Ltd (ULTC.NS)- Binani Cement Assets- MS.pdf   -  (35/590)
#
#  ['morganstanley']
#  ['Ashish.G.Jain', 'Mukund.Sarawogi']
#  ['ACC', 'TOTAL']
#  ['Ambuja Cements Ltd.', 'ACC Ltd.', 'Shree Cement Ltd.']
#
# Call : Buy  -  Price : 1.0
#
# EDEL_PULSE-conference_note-Aug-12-EDEL.pdf   -  (36/590)
#
#  ['edelcap']
#  ['Bhaskar']
#  ['M&M']
#  []
#
# Call : None  -  Price : None
#
# FromAnecdotetoAssessment.pdf   -  (37/590)
#
#  ['umich']
#  ['kthirolf']
#  []
#  []
#
# Call : None  -  Price : None
#
# sunhdfc.pdf   -  (38/590)
#
#  ['hdfcsec']
#  ['meeta.shetty']
#  ['HDFC', 'TOTAL', 'SUNP IN']
#  []
#
# Call : Sell  -  Price : 536.0
#
# Corona Audit_Report_2011-12.pdf   -  (39/590)
#
#  ['Others']
#  ['corona bus']
#  ['TOTAL', 'PEL']
#  ['Punjab National Bank']
#
# Call : None  -  Price : None
#
# Ambit_Ten Interesting Things_Weeklies_28Mar2018.pdf   -  (40/590)
#
#  ['ambit']
#  ['Sajid Merchant']
#  []
#  []
#
# Call : None  -  Price : None
#
# IndusInd Bank-Prabhudas Lilladher Q3FY17 Update.pdf   -  (41/590)
#
#  ['plindia']
#  ['vidhishah', 'rsreesankar', 'priteshbumb']
#  []
#  []
#
# Call : Sell  -  Price : 48.0
#
# India Steel UBS part 2.pdf   -  (42/590)
#  ['ubs']
#  ['william.vanderpump']
#  ['NMDC', 'SAIL', 'TI']
#  []
#
# Call : Buy  -  Price : 2015.0
#
# Bigbloc Const.  Investor presentation.pdf   -  (43/590)
#
#  ['sgapl']
#  ['cs_sumit']
#  ['TI']
#  []
#
# Call : None  -  Price : None
#
# VIP 1QFY17.pdf   -  (44/590)
#
#  ['sparkcapital']
#  ['tejash', 'madhav', 'gnanasundar']
#  ['GNA', 'TOTAL', 'VIP IN', 'MADHAV']
#  []
#
# Call : Buy  -  Price : 131.0
#
# UPLL-20181026-MOSL-RU-PG012.pdf   -  (45/590)
#
#  ['MotilalOswal']
#  ['Aksh.Vashishth', 'Sumant.Kumar']
#  ['UPLL IN', 'UPL']
#  []
#
# Call : Buy  -  Price : 749.0
#
# WHIRL-20171127-MOSL-CU-PG006.pdf   -  (46/590)
#
#  ['MotilalOswal']
#  ['Ankur.VSharma', 'Amit.Shah']
#  ['WHIRL IN']
#  []
#
# Call : None  -  Price : None
#
# Astral Poly.pdf   -  (47/590)
#
#  ['antiquelimited']
#  ['nehal.shah']
#  ['ASTRA IN']
#  []
#
# Call : None  -  Price : None
#
# IceCap Asset Management Limited Global Markets November 2011.pdf   -  (48/590)
#
#  ['IceCapAssetManagement']
#  ['keithdicker']
#  ['DOLLAR']
#  []
#
# Call : None  -  Price : None
#
# http___www.edelresearch.com_rpt_showPdf.aspx_id=20806&reportname=_BRAVEHEART_SERIES-Zee_Entertainment_Enterprises.pdf   -  (49/590)
#
#  ['Others']
#  ['Sridhar']
#  []
#  []
#
# Call : None  -  Price : None
#
# BLS_International-_2QFY18_-_HDFC_sec.pdf   -  (50/590)
#
#  ['hdfcsec']
#  ['apurva.prasad', 'amit.chandra']
#  ['BLS', 'TOTAL', 'LT', 'MARG', 'BLSIN IN', 'HDFC']
#  []
#
# Call : Sell  -  Price : 300.0
#
# Godrej Consumer products.pdf   -  (51/590)
#
#  ['MotilalOswal']
#  ['AmitPurohit', 'AmnishAggarwal', 'reports']
#  []
#  []
#
# Call : Buy  -  Price : 5.0
#
# AGLL-20170523-MOSL-RU-PG010.pdf   -  (52/590)
#
#  ['motilaloswal']
#  ['Varun.kumar']
#  ['FCL', 'ALLCARGO', 'AGLL IN']
#  []
#
# Call : Buy  -  Price : 228.0
#
# Antique Broking- Sector Report  Infrastructure & Construction Sector - On the cusp of recovery.pdf   -  (53/590)
#
#  ['antiquelimited']
#  ['dhaval.patel', 'rahul.modi']
#  ['MEP', 'NCC', 'ASBL IN', 'PNC', 'NH', 'SADBHAV', 'SINP IN', 'TRIL', 'IRB', 'ASHOKA', 'IDFC', 'NJCC IN', 'KNRC IN', 'IRB IN', 'SADE IN', 'HCC']
#  []
#
# Call : Buy  -  Price : 355.0
#
# BP Wealth- Kitex Garments Limited.pdf   -  (54/590)
#
#  ['Others']
#  ['Administrator']
#  ['KTG IN', 'KITEX']
#  []
#
# Call : None  -  Price : None
#
# FRC_Study_ETF_Executive%20Summary.pdf   -  (55/590)
#
#  ['frcnet']
#  ['craig.kilgallen', 'david.enns', 'elizabeth.wetherbee', 'deborah.wetherbee']
#  ['TIL', 'TI']
#  []
#
# Call : Sell  -  Price : 30.0
#
# Annual-Report2017-18.pdf   -  (56/590)
#
#  ['adityabirla']
#  ['kamal.r', 'brr.utcl']
#  ['ICICI', 'NH', 'TOTAL', 'LT', 'HDFC', 'UCL', 'ULTRACEMCO', 'BPL']
#  []
#
# Call : Sell  -  Price : 10.0
#
# MIConferenceBrochure.pdf   -  (57/590)
#
#  ['Others']
#  ['NA']
#  ['SCI']
#  []
#
# Call : None  -  Price : None
#
# Biocon - BAML.pdf   -  (58/590)
#
#  ['baml']
#  ['manoj.r.garg', 'akumar221']
#  ['APHS IN', 'CIPLA IN', 'CDH IN', 'LPC IN', 'GNP IN', 'DRRD IN', 'SUNP IN', 'BIOS IN', 'ARBP IN', 'CIPLA']
#  []
#
# Call : Buy  -  Price : 9.0
#
# BuffettWhartonspeech.pdf   -  (59/590)
#
#  ['Others']
#  ['Charles Kornblith']
#  []
#  []
#
# Call : None  -  Price : None
#
# correspondence2_p.pdf   -  (60/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# IDirect_Concor_Q4FY17.pdf   -  (61/590)
#
#  ['icicisecurities']
#  ['bharat.chhodal', 'pankaj.pandey', 'ankit.panchmatia', 'research']
#  ['ICICI']
#  []
#
# Call : Buy  -  Price : 1370.0
#
# Dolat- Rallis India- Key takeaways from the annual report.pdf   -  (62/590)
#
#  ['dolatcapital']
#  ['rajeshs']
#  ['ACC']
#  []
#
# Call : Sell  -  Price : 144.0
#
# aviationweek.pdf   -  (63/590)
#
#  ['Others']
#  ['Ranjit']
#  []
#  []
#
# Call : None  -  Price : None
#
# KPMG Flash News - New Companies Act, 2013 - Insight Series.pdf   -  (64/590)
#
#  ['Others']
#  ['KPMG\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c\x0c']
#  ['DLF']
#  []
#
# Call : None  -  Price : None
#
# HIL Ltd - IC - BP Equitiesb.pdf   -  (65/590)
#
#  ['bpwealth']
#  ['harshilshethia']
#  ['HIL', 'HIL IN']
#  ['HIL Ltd.']
#
# Call : None  -  Price : None
#
# Hudgins.pdf   -  (66/590)
#
#  ['odec']
#  ['dhudgins']
#  []
#  []
#
# Call : None  -  Price : None
#
# vedcmd_q_a_transcript.pdf   -  (67/590)
#
#  ['Others']
#  ['5928']
#  []
#  []
#
# Call : Buy  -  Price : 737.0
#
# The Front Page 20190325.pdf   -  (68/590)
#
#  ['iiflcap']
#  ['kunal.shah', 'rishi.jhunjhunwala', 'avi.mehta', 'ameya.karambelkar', 'mail', 'ala']
#  ['ICICI', 'INFOE IN', 'IIFL', 'HDFC', 'NTPC']
#  ['Punjab National Bank']
#
# Call : Sell  -  Price : 10.0
#
# Havells India Q1FY14 Result Update.pdf   -  (69/590)
#
#  ['emkayglobal']
#  ['pritesh.chheda', 'prashant.kutty']
#  []
#  ['Emkay Global Financial Services Ltd.']
#
# Call : None  -  Price : None
#
# Edelweiss Investment Banking_BFSI Newsletter (December  2015).pdf   -  (70/590)
#
#  ['Bloomberg']
#  ['Sameer Gaud']
#  ['PTC', 'RBL', 'IDBI', 'ICICI', 'PFC', 'IDFC', 'LT', 'DHFL', 'ICRA', 'HDFC', 'IFCI', 'CRISIL']
#  ['LIC Housing Finance Ltd.', 'United Bank of India', 'Syndicate Bank', 'Allahabad Bank', 'Punjab National Bank', 'Canara Bank', 'UCO Bank']
#
# Call : Buy  -  Price : 2016.0
#
# Emkay  Chambal Fertilisers Q2FY17 Result Update-074044.pdf   -  (71/590)
#
#  ['emkayglobal']
#  ['rohan.gupta', 'pratik.tholiya']
#  ['MCX', 'ACC', 'CHMB IN']
#  ['Emkay Global Financial Services Ltd.']
#
# Call : None  -  Price : None
#
# ICICI Direct- Talwarkar BetterValue.pdf   -  (72/590)
#
#  ['icicisecurities']
#  ['rashes.shah', 'pankaj.pandey', 'sneha.agarwal', 'research']
#  ['ICICI']
#  []
#
# Call : Buy  -  Price : 22.0
#
# Lupin UBS 100816.pdf   -  (73/590)
#
#  ['ubs']
#  ['hemant.bakhru']
#  ['SPECTRUM']
#  []
#
# Call : Buy  -  Price : 2200.0
#
# IN_en.pdf   -  (74/590)
#
#  ['un']
#  ['india', 'indiaun']
#  []
#  []
#
# Call : None  -  Price : None
#
# Banks_NBFCs_-_4QFY17_Results_Preview_-_HDFC_sec.pdf   -  (75/590)
#
#  ['hdfcsec']
#  ['darpin.shah', 'vishal.rampuria', 'pranav.gupta']
#  ['ICICI', 'AVG', 'UJJIVAN', 'SBIN', 'EQUITAS', 'CUB', 'HDFC']
#  []
#
# Call : None  -  Price : None
#
# Telecom_Vodafone_Idea_merger_Jan17.pdf   -  (76/590)
#
#  ['icicisecurities']
#  ['sanjesh.jain']
#  ['ICICI']
#  []
#
# Call : None  -  Price : None
#
# TI Annual Report 08-09.pdf   -  (77/590)
#
#  ['tilind']
#  ['tiliquor', 'ssingh']
#  ['THE IN', 'CLASSIC', 'HDFC', 'TI']
#  ['HDFC Bank Ltd.', 'Axis Bank Ltd.', 'Tilaknagar Industries Ltd.', 'Yes Bank Ltd.']
#
# Call : Sell  -  Price : 16.0
#
# The benefits of being a real fraudster - FT.pdf   -  (78/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# IDirect_Greenply_IC.pdf   -  (79/590)
#
#  ['icicisecurities']
#  ['vaibhav.shah', 'pankaj.pandey', 'research']
#  ['HSIL', 'ICICI']
#  []
#
# Call : Buy  -  Price : 44.0
#
# kotak ecommerce.pdf   -  (80/590)
#
#  ['kotak']
#  ['akhilesh.tilotia', 'kotak.research']
#  ['MCX']
#  []
#
# Call : Sell  -  Price : 12.0
#
# Space.pdf   -  (81/590)
#
#  ['Others']
#  ['e28098']
#  []
#  []
#
# Call : None  -  Price : None
#
# CG Power - Elara-.pdf   -  (82/590)
#
#  ['elaracapital']
#  ['welcome']
#  ['CGPOWER IN', 'ACC', 'CGPOWER']
#  []
#
# Call : Buy  -  Price : 85.0
#
# Thomas Cook (I).pdf   -  (83/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# ivey-executive-program.pdf   -  (84/590)
#
#  ['ivey']
#  ['']
#  []
#  []
#
# Call : None  -  Price : None
#
# Audited Financial Results_30.06.2014.pdf   -  (85/590)
#
#  ['nlage']
#  ['Per']
#  ['SYMPHONY', 'TOTAL']
#  []
#
# Call : None  -  Price : None
#
# IndiaMorningBrief_13June2018.pdf   -  (86/590)
#
#  ['jmfl']
#  ['Rupesh Sonawale']
#  ['ONGC', 'ICICI', 'M&M', 'PNB', 'GAIL', 'UPL', 'HDFC', 'SRF', 'BHEL', 'GTPL', 'NTPC', 'SAIL', 'TI']
#  ['UPL Ltd.', 'Sobha Ltd.', 'Punjab National Bank', 'Canara Bank', 'Marico Ltd.', 'Indian Bank']
#
# Call : Buy  -  Price : 14.0
#
# ConsumerStaples-17-11-11-PL.pdf   -  (87/590)
#
#  ['plindia']
#  ['gautamduggal']
#  ['ITC']
#  []
#
# Call : None  -  Price : None
#
# Ambit - Bajaj Finance (SELL) errclub Steep valuations and rising risks.pdf   -  (88/590)
#
#  ['ambitcapital']
#  ['ravisingh', 'aadeshmehta', 'pankajagarwal', 'joelpereira']
#  ['ICICI', 'M&M', 'BAF IN', 'HDFC']
#  []
#
# Call : Sell  -  Price : 14.0
#
# BNK_SONA@IN_021715_161235.pdf   -  (89/590)
#
#  ['bksec']
#  ['annamalai.jayaraj', 'kartik.rajpara']
#  []
#  []
#
# Call : Buy  -  Price : 53.0
#
# Career Launcher Investment Kit.pdf   -  (90/590)
#
#  ['Others']
#  ['ks']
#  []
#  []
#
# Call : None  -  Price : None
#
# Citi - India Budget.pdf   -  (91/590)
#
#  ['citi']
#  ['surendra.goyal', 'samiran.chakraborty', 'anurag.jha', 'vijit.jain', 'siddharth.mathur']
#  ['M&M', 'NH', 'GAIL', 'IDEA', 'ITC']
#  []
#
# Call : Buy  -  Price : 2015.0
#
# FoE-20180208-MOSL-ES-PG006.pdf   -  (92/590)
#  ['motilaloswal']
#  ['Nikhil.Gupta', 'Rahul.Agrawal']
#  ['HUDCO']
#  []
#
# Call : None  -  Price : None
#
# Balkrishna Inds quant.pdf   -  (93/590)
#
#  ['Others']
#  ['NA']
#  ['PEL']
#  []
#
# Call : None  -  Price : None
#
# EY-Tax-Alert-key-proposals-of-the-Direct-Taxes-Code-2010%20.pdf   -  (94/590)
#
#  ['Others']
#  ['sudhir.masuti']
#  []
#  []
#
# Call : None  -  Price : None
#
# Millennials to Anchor India's Growth Story.pdf   -  (95/590)
#
#  ['morganstanley']
#  [None]
#  ['HDFC', 'TOTAL']
#  []
#
# Call : Buy  -  Price : 12.0
#
# Goodyear+India+-+Stock+Note.pdf   -  (96/590)
#
#  ['hdfcsec']
#  ['hdfcsecretailresearch']
#  ['M&M', 'GDYR IN', 'GOODYEAR', 'HDFC']
#  ['Cash & Cash Equivalent', 'Goodyear India Ltd.']
#
# Call : None  -  Price : None
#
# UPL (1QFY19) - HDFC sec.pdf   -  (97/590)
#
#  ['hdfcsec']
#  ['archit.joshi', 'nilesh.ghuge']
#  ['UPLL IN', 'TOTAL', 'LT', 'UPL', 'HDFC']
#  []
#
# Call : None  -  Price : None
#
# ESIB Bajaj Finserve1.pdf   -  (98/590)
#
#  ['espiritosantoib']
#  ['Santosh Singh, CFA']
#  ['BJFIN IN', 'AMBER', 'SIL']
#  []
#
# Call : Buy  -  Price : 2.0
#
# H016615261.pdf   -  (99/590)
#
#  ['Others']
#  ['Rajendra']
#  []
#  []
#
# Call : None  -  Price : None
#
# It services 2.pdf   -  (100/590)
#
#  ['ubs']
#  ['michael.briest', 'peter.christiansen', 'diviya.nagarajan', 'steven.milunovich', 'tal.grant']
#  ['INFY', 'TCS']
#  ['Wipro Ltd.', 'Tata Consultancy Services Ltd.']
#
# Call : Buy  -  Price : 660.0
#
# DCM Ltd Report.pdf   -  (101/590)
#
#  ['yahoo']
#  ['annu_agg007']
#  ['ICICI', 'DCM', 'HDFC', 'IFCI', 'RITES']
#  ['Force Motors Ltd.', 'Ashok Leyland Ltd.', 'DCM Ltd.', 'Mahindra & Mahindra Ltd.', 'Maruti Suzuki India Ltd.']
#
# Call : None  -  Price : 140.0
#
# 10_chapter 5.pdf   -  (102/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# AMP - 210316.pdf   -  (103/590)
#
#  ['antiquelimited']
#  ['jigar.shah', 'basudeb.banerjee', 'digant.haria']
#  ['ONGC', 'LUPIN', 'IRB', 'ITC', 'BHEL', 'GLENMARK', 'INFRATEL', 'APOLLOTYRE', 'BEML', 'NTPC', 'SIEMENS', 'POWERGRID', 'GRUH', 'REPCO IN', 'GRHF IN', 'LT', 'MOIL', 'IOC', 'TCS', 'HDFC', 'APOLLO', 'HSIL', 'ICICI', 'M&M', 'GAIL', 'OIL', 'ICRA', 'SAIL', 'MRF', 'NMDC', 'ACC', 'KEC', 'MUNI IN', 'PTC', 'MEP', 'NH', 'VOLTAS', 'HINDPETRO', 'CONCOR', 'ABB', 'CESC', 'BPCL', 'CENTURYTEX']
#  ['Canara Bank', 'Punjab National Bank']
#
# Call : Buy  -  Price : 362.0
#
# Granules_-_2QFY18_-_HDFC_sec.pdf   -  (104/590)
#
#  ['hdfcsec']
#  ['amey.chalke', 'siddhant.mansukhani']
#  ['GRAN IN', 'TOTAL', 'GRANULES', 'HDFC']
#  []
#
# Call : Sell  -  Price : 170.0
#
# Ambit_Walk in the woods_Fortnightly_What we are hearing_18July2018.pdf   -  (105/590)
#
#  ['ambit']
#  ['Karan Khanna']
#  []
#  []
#
# Call : None  -  Price : None
#
# MCX_Edel.pdf   -  (106/590)
#
#  ['edelweissfin']
#  ['kunal.shah', 'prakhar.agarwal', 'aditya.narain']
#  ['ICICI', 'IDFC', 'HDFC', 'MCX']
#  ['Allahabad Bank', 'Punjab National Bank', 'Union Bank Of India', 'Equitas Holdings Ltd.', 'Oriental Bank Of Commerce']
#
# Call : Buy  -  Price : 28.0
#
# AR032012.pdf   -  (107/590)
#
#  ['finolexind']
#  ['E-mail:bhargaves', 'E-mail:investors', 'investors']
#  ['IDBI', 'ICICI', 'TOTAL', 'FINPIPE', 'HDFC', 'NOCIL', 'PRAKASH']
#  ['Corporation Bank', 'Finolex Cables Ltd.', 'Punjab National Bank']
#
# Call : Sell  -  Price : 21.0
#
# Against the Tide.pdf   -  (108/590)
#
#  ['antiquelimited']
#  ['Anant Bhosle']
#  ['SOTL', 'ISL IN', 'ALOK IN', 'PSL', 'GDSP IN', 'GITG IN', 'HCC', 'ILFT IN', 'ORB IN', 'JSTL IN', 'DEN', 'OINL IN', 'NBVL IN', 'SKNL IN', 'DEN IN', 'OIL', 'SOTL IN', 'CESC', 'BPCL', 'MCX']
#  ['Reliance Infrastructure Ltd.', 'Bharat Petroleum Corporation Ltd.', 'JSW Steel Ltd.', 'Ind-Swift Laboratories Ltd.']
#
# Call : Sell  -  Price : 2007.0
#
# Global Logistics.pdf   -  (109/590)
#
#  ['glprop']
#  ['agoel']
#  ['LT']
#  []
#
# Call : None  -  Price : None
#
# APNT-20160727-MOSL-RU-PG008.pdf   -  (110/590)
#
#  ['motilaloswal']
#  ['kadambari.balachandran', 'Varun.kumar']
#  ['APNT IN']
#  []
#
# Call : Buy  -  Price : 3.0
#
# KMB-20141121-MOSL-CU-PG014.pdf   -  (111/590)
#
#  ['motilaloswal']
#  ['reports', 'Alpesh.Mehta', 'kadambari.balachandran', 'Email:anosh.Koppikar', 'Vallabh.Kulkarni']
#  ['ICICI', 'KMB IN', 'HDFC']
#  []
#
# Call : Buy  -  Price : 41.0
#
# The Federal Bank Ltd. Insights - Earnings recover, valuation comfortable.pdf   -  (112/590)
#
#  ['emis']
#  ['prane']
#  ['RBL', 'ICICI', 'CUB', 'HDFC']
#  []
#
# Call : Sell  -  Price : 1.0
#
# just dial - 240913 - centrum.pdf   -  (113/590)
#
#  ['centrum']
#  ['Ankit.kedia']
#  ['TCS', 'IDEA', 'CDSL', 'MCX', 'HDFC', 'JUST IN']
#  []
#
# Call : Sell  -  Price : 902.0
#
# BHEL 2QFY18 Outlook Review.pdf   -  (114/590)
#
#  ['sparkcapital']
#  ['sriram', 'ravi']
#  ['TOTAL', 'BHEL IN', 'BHEL', 'SRIRAM']
#  []
#
# Call : Sell  -  Price : 83.0
#
# ABD-20150318-MOSL-CF-PG004.pdf   -  (115/590)
#
#  ['motilaloswal']
#  ['Manish.Poddar', 'reports', 'kadambari.balachandran', 'anosh.Koppikar', 'Gautam.Duggad']
#  []
#  []
#
# Call : None  -  Price : None
#
# JUST_1QFY17 result review.pdf   -  (116/590)
#
#  [' 22x']
#  ['469']
#  ['JUST IN', 'TOTAL']
#  []
#
# Call : None  -  Price : 3.0
#
# EDELFLASH_-_FERTILISERS_-_GAS_PRICE_HIKE_TO_IMPACT_ADVERSELY-13-JAN-14.pdf   -  (117/590)
#
#  ['edelweissfin']
#  ['nischal.maheshwari', 'manoj.bahety', 'vikas.khemani', 'nirav.sheth', 'manish.mahawar']
#  []
#  []
#
# Call : Buy  -  Price : 2014.0
#
# BOAML-BhagMilkhaBhag.pdf   -  (118/590)
#
#  ['baml']
#  ['indranil.sengupta']
#  ['TI']
#  []
#
# Call : None  -  Price : None
#
# enam_voltas.pdf   -  (119/590)
#
#  ['enam']
#  ['kashyap.pujara', 'farzan.madon']
#  []
#  []
#
# Call : Buy  -  Price : 74.0
#
# nestle.pdf   -  (120/590)
#
#  ['Others']
#  ['toufiq.l']
#  ['HDFC', 'ICICI']
#  []
#
# Call : Buy  -  Price : 12.0
#
# Antique Broking- Management Meet Update India Banking -errclub TransUnion CIBIL - Retail underwriting remain strong.pdf   -  (121/590)
#
#  ['antiquelimited']
#  ['nitin.aggarwal', 'renish.patel']
#  []
#  []
#
# Call : None  -  Price : None
#
# DB - UPL.pdf   -  (122/590)
#
#  ['db']
#  ['amit.murarka']
#  ['UPL', 'UPLL IN']
#  []
#
# Call : None  -  Price : None
#
# Kotak_15Jan16_Consumer_Querimetrix.pdf   -  (123/590)
#
#  ['&']
#  ['INITIAL ']
#  ['MARUTI', 'TOTAL', 'NETWORK']
#  []
#
# Call : Buy  -  Price : 10.0
#
# ice cap asset - shoe view - jan14.pdf   -  (124/590)
#
#  ['IceCapAssetManagement']
#  ['keithdicker']
#  ['BANG']
#  []
#
# Call : None  -  Price : None
#
# EDEL- Media - Hits ‘n’ Misses errclub Share gains amidst demonetisation blues.pdf   -  (125/590)
#
#  ['edelweissfin']
#  ['abneesh.roy', 'rajiv.berlia', 'manoj.bahety']
#  ['PVR', 'TI']
#  []
#
# Call : None  -  Price : None
#
# JMFL– Sun TV Network -errclub- Business becoming more Tamil-centric, stock remains undervalued.pdf   -  (126/590)
#
#  ['jmfl']
#  ['sanjay.chawla', 'zeeshan.bagwan']
#  []
#  []
#
# Call : Buy  -  Price : 450.0
#
# BAFL MAy 2016 Concall Transcripts.pdf   -  (127/590)
#
#  ['Others']
#  ['(anonymous)']
#  []
#  []
#
# Call : Sell  -  Price : 3.0
#
# India+consumer+sector+Nov+12.pdf   -  (128/590)
#
#  ['credit-suisse']
#  ['akshay.saxena', 'arnab.mitra']
#  ['ITC']
#  []
#
# Call : Sell  -  Price : 2012.0
#
# em_20_anniversary.pdf   -  (129/590)
#
#  [' Turkey']
#  ['clientservice', 'sat ']
#  ['LT']
#  []
#
# Call : None  -  Price : None
#
# Cement Sector - Monthly Update - 28 Mar 18.pdf   -  (130/590)
#
#  ['bksec']
#  ['amit.srivastava', 'saurabh.mitra']
#  ['ACC']
#  []
#
# Call : Buy  -  Price : 310.0
#
# federal.pdf   -  (131/590)
#
#  ['Others']
#  ['NEW']
#  ['CHI']
#  []
#
# Call : None  -  Price : None
#
# Axis Direct- Aurobindo - In-line EBITDA; US growth visibility remains.pdf   -  (132/590)
#
#  ['axissecurities']
#  ['akhand.singh', 'sankar.narayanan']
#  []
#  []
#
# Call : Buy  -  Price : 940.0
#
# pn5_2005.pdf   -  (133/590)
#
#  ['Others']
#  ['grip']
#  []
#  []
#
# Call : None  -  Price : None
#
# Kirloskar Oil Engines_IC_5 May 2016.pdf   -  (134/590)
#
#  ['rathi']
#  ['bhalchandrashinde', 'premkhurana']
#  ['M&M', 'LT', 'HMT', 'TIL', 'BEML', 'TI']
#  []
#
# Call : Buy  -  Price : 5.0
#
# Conviction Ideas- Goodricke Group.pdf   -  (135/590)
#
#  ['capstocksindia']
#  ['research']
#  ['FDC', 'HSIL', 'IDFC', 'ITC', 'IGL', 'CRISIL']
#  []
#
# Call : Buy  -  Price : 205.0
#
# Media_Report_18Sept2017.pdf   -  (136/590)
#
#  ['jmfl']
#  ['shilpa.pattnaik', 'ruchir.jhunjhunwala', 'sunny.shah', 'sanjay.chawla', 'jmfinancial.research']
#  ['ADSL', 'NCC', 'DEN', 'ITC', 'ZEEL', 'GTPL']
#  ['Ortel Communications Ltd.']
#
# Call : Sell  -  Price : None
#
# Emkay- Sector Update Automobiles.pdf   -  (137/590)
#  ['emkayglobal']
#  ['raghunandhan.nl', 'bibhishan.jagtap']
#  ['ACC']
#  ['Emkay Global Financial Services Ltd.']
#
# Call : None  -  Price : None
#
# I-Sec_Mn150517.pdf   -  (138/590)
#
#  ['icicisecurities']
#  ['715370']
#  ['ABFRL', 'PNB', 'GSPL', 'HMVL', 'MHRIL', 'OCL', 'IOC', 'HDFC', 'HSIL', 'ICICI', 'GAIL', 'OIL', 'ATFL', 'BEL', 'CONCOR', 'ZEEL', 'CESC', 'BPCL', 'MCX']
#  ['Canara Bank']
#
# Call : Buy  -  Price : 3.0
#
# AMRJ-20170123-MOSL-RU-PG010.pdf   -  (139/590)
#
#  ['motilaloswal']
#  ['Varun.kumar']
#  ['ICICI', 'M&M', 'AMAR', 'AMRJ IN']
#  []
#
# Call : Buy  -  Price : None
#
# BAFL QIP - List of allottees-11062015.pdf   -  (140/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# Wabco India 2QFY18 Outlook Review.pdf   -  (141/590)
#
#  ['sparkcapital']
#  ['rseshan', 'mukesh']
#  ['WIL IN', 'TOTAL', 'STAN']
#  []
#
# Call : Buy  -  Price : 173.0
#
# 3TUHR8XDFPGYI62CJ5MQK14LSW7EBO.pdf   -  (142/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# EIL_IDFC - July12 .pdf   -  (143/590)
#
#  ['idfc']
#  ['santosh.fernandes']
#  ['IDFC', 'ENGR IN']
#  []
#
# Call : Sell  -  Price : 2.0
#
# TTKPHARM_20120116.pdf   -  (144/590)
#
#  ['firstcallindiaequity']
#  ['info']
#  []
#  ['TTK Healthcare Ltd.']
#
# Call : Sell  -  Price : 4.0
#
# V-Guard Transcript Jan'14.pdf   -  (145/590)
#
#  ['Others']
#  ['Amsec']
#  []
#  []
#
# Call : Sell  -  Price : 6.0
#
# ICICI UBS.pdf   -  (146/590)
#
#  ['ubs']
#  ['ishank.kumar', 'vishal.goyal']
#  ['SPECTRUM', 'ICICI']
#  []
#
# Call : Buy  -  Price : 260.0
#
# r101028a.pdf   -  (147/590)
#
#  ['Others']
#  ['BIS - Bank for International Settlements']
#  ['PNC']
#  []
#
# Call : None  -  Price : None
#
# june_2008_ubs_presentation.pdf   -  (148/590)
#
#  ['Others']
#  ['A0002595']
#  []
#  []
#
# Call : None  -  Price : None
#
# iuu02n30-3osq-g007-bf29-984be168e003.pdf   -  (149/590)
#
#  ['morganstanley']
#  ['Ridham.Desai', 'Utkarsh.Khandelwal', 'Sheela.Rathi']
#  ['TOTAL']
#  []
#
# Call : Sell  -  Price : 800.0
#
# IceCapAssetManagementLimitedGlobalMarketsJuly2010.pdf   -  (150/590)
#
#  ['IceCapAssetManagement']
#  ['keithdicker']
#  []
#  []
#
# Call : None  -  Price : None
#
# BUDGET_PREVIEW_FY14-JUN-14-EDEL.pdf   -  (151/590)
#
#  ['edelweissfin']
#  ['nischal.maheshwari', 'kapil.gupta', 'vikas.khemani', 'nirav.sheth', 'prateek.parekh']
#  ['ONGC', 'TOTAL', 'OIL', 'PSB']
#  []
#
# Call : Sell  -  Price : 58.0
#
# La Opala 2011.pdf   -  (152/590)
#
#  ['rediffmail']
#  ['mcskol']
#  ['HDFC', 'LAOPALA', 'TOTAL']
#  ['Genesis Exports Ltd.', 'Punjab Chemicals & Crop Protection Ltd.']
#
# Call : None  -  Price : None
#
# TVSL-20170427-MOSL-RU-PG014.pdf   -  (153/590)
#
#  ['motilaloswal']
#  ['Varun.kumar']
#  ['TVSL IN', 'RELIANCE', 'ICICI', 'M&M']
#  []
#
# Call : Buy  -  Price : 581.0
#
# Ambit_Ten Interesting Things_Weeklies_25Jan2018.pdf   -  (154/590)
#
#  ['ambit']
#  [None]
#  []
#  []
#
# Call : None  -  Price : None
#
# GujaratAmbujaExportsLtd (2).pdf   -  (155/590)
#
#  ['Others']
#  ['NA']
#  ['LT']
#  ['Gujarat Ambuja Exports Ltd.']
#
# Call : Buy  -  Price : 88.0
#
# ICIL_Q2FY16_Investor_Update_Presentation.pdf   -  (156/590)
#
#  ['Others']
#  ['icraadmin']
#  ['MARG', 'ICRA']
#  []
#
# Call : None  -  Price : None
#
# Axis Bank 2QFY19 result update - 181103 - Antique Research.pdf   -  (157/590)
#
#  ['antiquelimited']
#  ['amit.mishra', 'sohail.halai']
#  ['AXSB IN']
#  []
#
# Call : Buy  -  Price : 680.0
#
# AMP - 180502.pdf   -  (158/590)
#
#  ['antiquelimited']
#  ['rahul.gajare', 'digant.haria', 'bhavik.mehta', 'prateek.kumar', 'dhirendra.tiwari', 'nishant.shah']
#  ['ONGC', 'PNB', 'CGPOWER', 'IRB', 'HDFC IN', 'ITC', 'BIOCON', 'BHEL', 'CANBK', 'BEML', 'PCJEWELLER', 'NCC', 'BALRAMCHIN', 'RCOM', 'GRUH', 'LT', 'MOIL', 'UPL', 'TCS', 'HDFC', 'RBL', 'ICICI', 'RBLBANK', 'M&M', 'YESBANK', 'GAIL', 'IDFC', 'BALKRISIND', 'NBCC', 'OIL', 'LT IN', 'ICRA', 'SAIL', 'CANFINHOME', 'NMDC', 'ACC', 'KEC', 'PTC', 'CCRI IN', 'NATIONALUM', 'MARICO', 'ABB', 'BPCL', 'AXISBANK']
#  ['Sangam (India) Ltd.', 'Punjab National Bank', 'Canara Bank', 'NCC Ltd.']
#
# Call : Buy  -  Price : 672.0
#
# Liberty Shoes Q3FY14 Result Update.pdf   -  (159/590)
#
#  ['hdfcsec']
#  ['mehernosh.panthaki', 'hdfcsecretailresearch']
#  ['HDFC']
#  ['Liberty Shoes Ltd.']
#
# Call : Buy  -  Price : 156.0
#
# LT-28-7-17-PL.pdf   -  (160/590)
#
#  ['plindia']
#  ['kunalsheth']
#  []
#  []
#
# Call : None  -  Price : None
#
# VOLT 1QFY17 Review.pdf   -  (161/590)
#
#  [' 22x']
#  ['344']
#  ['VOLT IN', 'TOTAL']
#  []
#
# Call : Buy  -  Price : 392.0
#
# Colgate Palmolive (India) (COLG.BO) - Citi.pdf   -  (162/590)
#
#  ['citi']
#  ['aditya.mathur', 'jamshed.dadabhoy']
#  []
#  []
#
# Call : Buy  -  Price : 850.0
#
# Waiver loan_19Dec'18.pdf   -  (163/590)
#
#  ['jmfl']
#  ['zack']
#  []
#  []
#
# Call : None  -  Price : None
#
# 2012_india.pdf   -  (164/590)
#
#  ['in']
#  ['akash.gupt', 'vivek.mehra', 'gautam.mehra', 'sanjeev.krishan']
#  []
#  []
#
# Call : Sell  -  Price : 2012.0
#
# JagranPrakashan151216xe261629.pdf   -  (165/590)
#
#  ['macquarie']
#  ['alankar.garude']
#  ['JAGP IN']
#  []
#
# Call : Sell  -  Price : 25.0
#
# Ambit India Access_Little Giants Day_18Dec2017.pdf   -  (166/590)
#
#  ['sageoneinvestments']
#  ['research']
#  []
#  []
#
# Call : None  -  Price : None
#
# macroperspective.pdf   -  (167/590)
#
#  ['Frb']
#  ['m1sas00', 'mailto:ivo.welch']
#  []
#  []
#
# Call : None  -  Price : None
#
# Citi- Petronet LNG (PLNG.BO) - 3Q - EBITDA Expectedly Soft, But Volumes Surprise Positively.pdf   -  (168/590)
#
#  ['citi']
#  ['saurabh.handa', 'sohini1.banerjee']
#  ['GSPL']
#  []
#
# Call : Buy  -  Price : 24.0
#
# CITUNIBA_20120806.pdf   -  (169/590)
#
#  ['icicisecurities']
#  ['research', 'jaymin.trivedi', 'vasant.lohiya', 'kajal.gandhi', 'pankaj.pandey']
#  ['IDBI', 'ICICI', 'CUB', 'HDFC']
#  ['Syndicate Bank', 'Indian Overseas Bank', 'Punjab National Bank']
#
# Call : Buy  -  Price : 60.0
#
# Cover Page - EBook Sourajit Aiyer.pdf   -  (170/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# HDFC Sec_Banks & NBFC Sector_Q1FY17 Preview_08072016.pdf   -  (171/590)
#
#  ['hdfcsec']
#  ['siji.philip', 'darpin.shah', 'parul.gulati']
#  ['ICICI', 'UJJIVAN', 'AVG', 'SBIN', 'CUB', 'HDFC']
#  []
#
# Call : None  -  Price : None
#
# VP Chemical Presentation.pdf   -  (172/590)
#
#  ['JM’s report on Speciality Chemicals dated']
#  ['Bena']
#  ['BASF']
#  []
#
# Call : None  -  Price : None
#
# 2015-08-07_1438962126.pdf   -  (173/590)
#
#  ['ilfsindia']
#  ['devang.patel']
#  ['BHEL', 'BHEL IN']
#  []
#
# Call : Sell  -  Price : 12.0
#
# Axis Direct- AIA Engineering - Mining volumes pick up.pdf   -  (174/590)
#
#  ['axissecurities']
#  ['akhand.singh', 'sankar.narayanan']
#  []
#  []
#
# Call : None  -  Price : None
#
# India Asset Management - Monthly Update - JM Financial.pdf   -  (175/590)
#
#  ['jmfl']
#  ['Equitec-3']
#  ['ICICI']
#  []
#
# Call : None  -  Price : None
#
# GS- Titan Industries (TITN.BO) err In line with expectations Higher margins offset lower Tanishq sales.pdf   -  (176/590)
#
#  ['gs']
#  ['indrajit.agarwal', 'puneet.jain', 'aditya.soman']
#  []
#  []
#
# Call : None  -  Price : None
#
# GC14-4880_2.pdf   -  (177/590)
#
#  ['AVAC Ltd.']
#  ['Rosivaldo Novaes']
#  []
#  []
#
# Call : None  -  Price : None
#
# IT-20150309-MOSL-WOW-PG006.pdf   -  (178/590)
#
#  ['motilaloswal']
#  ['reports', 'kadambari.balachandran', 'Ashish.Chopra', 'Siddharth.Vora', 'anosh.Koppikar']
#  ['TECHM', 'TCS']
#  []
#
# Call : None  -  Price : None
#
# JustDial-IPO - trust.pdf   -  (179/590)
#
#  ['Trust']
#  ['Rajesh Mhatre']
#  ['LT']
#  []
#
# Call : Sell  -  Price : 2470.0
#
# CRG 1QFY16 Review.pdf   -  (180/590)
#
#  ['sparkcapital']
#  ['raghavan', 'ravi']
#  []
#  []
#
# Call : Sell  -  Price : None
#
# ENGG-20141014-MOSL-FC-PG008.pdf   -  (181/590)
#
#  ['motilaloswal']
#  ['reports', 'kadambari.balachandran', 'Nirav.Vasa', 'Amit.Shah', 'Email:anosh.Koppikar', 'AgarwalS']
#  ['KEC', 'LT', 'ABB', 'BHEL']
#  []
#
# Call : None  -  Price : None
#
# Conviction Ideas - Raymond.pdf   -  (182/590)
#
#  ['capstocksindia']
#  ['research']
#  ['FDC', 'IDFC', 'ITC', 'IGL', 'CRISIL']
#  []
#
# Call : Buy  -  Price : 235.0
#
# TELX-20170127-MOSL-RU-PG010.pdf   -  (183/590)
#
#  ['motilaloswal']
#  ['Varun.kumar']
#  ['TELX IN']
#  []
#
# Call : Buy  -  Price : 5.0
#
# BHE-8-8-16-PL.pdf   -  (184/590)
#
#  ['plindia']
#  ['kunalsheth', 'samirbendre']
#  ['BEL']
#  []
#
# Call : None  -  Price : None
#
# Ambit India Access_Pre-Budget Conference Call with Dinesh Kanabar_25Jan2018.pdf   -  (185/590)
#
#  ['sageoneinvestments']
#  ['research']
#  []
#  []
#
# Call : None  -  Price : None
# AmbitCap-Hathway-Nov19-2013.pdf   -  (186/590)
#
#  ['y,']
#  ['athw', 'hathw']
#  []
#  []
#
# Call : None  -  Price : None
#
# vhf-interim-guidance.pdf   -  (187/590)
#
#  ['Others']
#  ['bzw8']
#  []
#  []
#
# Call : None  -  Price : None
#
# The Option Trader Handbook - Strategies And Trade Adjustments.pdf   -  (188/590)
#
#  ['  $45']
#  ['YHOO  ', 'EBAY  ', 'IBM  ']
#  ['TI']
#  []
#
# Call : Sell  -  Price : 100.0
#
# Cera Presentation.pdf   -  (189/590)
#
#  ['gmail']
#  ['ankurjain2100']
#  ['MTNL', 'CERA']
#  ['Cash & Cash Equivalent']
#
# Call : Buy  -  Price : 42.0
#
# Alcoholic_Beverages_Jun162.pdf   -  (190/590)
#
#  ['icicisecurities']
#  ['anand.mour', 'Aniruddha.joshi']
#  ['ICICI']
#  []
#
# Call : None  -  Price : None
#
# AXSB-20171113-MOSL-CU-PG008.pdf   -  (191/590)
#
#  ['MotilalOswal']
#  ['Alpesh.Mehta', 'Piran.Engineer', 'Nitin.Aggarwal', 'Anirvan.Sarkar']
#  ['AXSB IN']
#  []
#
# Call : Buy  -  Price : 680.0
#
# IDEA-20170213-MOSL-RU-PG012.pdf   -  (192/590)
#
#  ['motilaloswal']
#  ['Varun.kumar']
#  ['ICICI', 'IDEA IN', 'IDEA']
#  ['ICICI Prudential Life Insurance Company Ltd.']
#
# Call : Sell  -  Price : 22.0
#
# [Kotak] Telecommunication Services, December 18, 2018.pdf   -  (193/590)
#
#  ['kotak']
#  ['aniket.sethi', 'kotak.research', 'rohit.chordia']
#  []
#  []
#
# Call : None  -  Price : 12.0
#
# ICRA nov 2013.pdf   -  (194/590)
#
#  ['edelweissfin']
#  ['nischal.maheshwari', 'manoj.bahety', 'shradha.sheth', 'vikas.khemani', 'nirav.sheth']
#  ['ICRA', 'CRISIL']
#  []
#
# Call : Buy  -  Price : 74.0
#
# UTILITY-DISCOM-20150313-MOSL-ROH-PG014.pdf   -  (195/590)
#
#  ['motilaloswal']
#  ['kadambari.balachandran', 'reports', 'anosh.Koppikar', 'nalinbhatt']
#  ['PTC', 'NH', 'NHPC', 'CESC', 'NTPC']
#  []
#
# Call : Buy  -  Price : 1.0
#
# Thejo_RHP_Final.pdf   -  (196/590)
#
#  ['idbicapital']
#  ['IDBI Capital']
#  ['SJVN', 'IDBI', 'ARE IN', 'TOTAL', 'FAME', 'LT', 'NESCO', 'CDSL', 'MOIL', 'NBCC', 'HDFC', 'NTPC', 'THEJO', 'SAIL', 'BPL']
#  ['Powerica Ltd.', 'Electrotherm (India) Ltd.']
#
# Call : Sell  -  Price : 10.0
#
# Keeping%20Condensers%20Clean%20POWER%200406.pdf   -  (197/590)
#
#  ['Others']
#  ['sls']
#  []
#  []
#
# Call : None  -  Price : None
#
# DrReddys_Flash_290316.pdf   -  (198/590)
#
#  ['jmfl']
#  ['kunal.randeria', 'anmol.ganjoo']
#  []
#  []
#
# Call : Sell  -  Price : None
#
# iSec- VRL Logistics.pdf   -  (199/590)
#
#  ['icicisecurities']
#  ['sandeep.mathew']
#  ['ICICI']
#  []
#
# Call : Buy  -  Price : 332.0
#
# Tyre sector update - 170130.pdf   -  (200/590)
#
#  ['antiquelimited']
#  ['jigar.shah', 'basudeb.banerjee']
#  ['JKI IN', 'CEAT IN', 'APTY IN', 'MRF']
#  []
#
# Call : Buy  -  Price : 220.0
#
# 2008_03_IR_Book_en (2).pdf   -  (201/590)
#
#  ['Others']
#  ['..']
#  []
#  []
#
# Call : Sell  -  Price : 15.0
#
# Cera Sanitaryware Ltd  (2).pdf   -  (202/590)
#
#  ['crisil']
#  ['dinakarann']
#  ['CERA', 'CRISIL']
#  []
#
# Call : None  -  Price : None
#
# Dollar Industries.pdf   -  (203/590)
#
#  ['dollarglobal']
#  ['•\u202fshashi.agarwal']
#  ['DOLLAR IN', 'DOLLAR']
#  []
#
# Call : None  -  Price : None
#
# Info_Edge_Q4FY17.pdf   -  (204/590)
#
#  ['icicisecurities']
#  ['bhrugesh.parsawala', 'kuldeep.koul']
#  ['ICICI']
#  []
#
# Call : Buy  -  Price : 960.0
#
# Lokusdesign Credentials 200115.pdf   -  (205/590)
#
#  ['honaywell']
#  ['servicewnrld', 'LCD ', 'Training ', 'serviceworld']
#  ['INFINITE', 'SUZLON', 'TCS', 'HAVELLS', 'SPIC']
#  []
#
# Call : None  -  Price : None
#
# AmbitInsights_08Aug2016.pdf   -  (206/590)
#
#  ['ambitcapital']
#  [None]
#  ['KKC IN', 'KEC', 'TTAN IN', 'TCS', 'LT', 'ITC', 'UNBK IN', 'IGL', 'ABB', 'SRF', 'BHEL', 'NTPC', 'AMBER', 'MRF']
#  ['Atul Ltd.', 'Union Bank Of India', 'MRF Ltd.']
#
# Call : Sell  -  Price : 404.0
#
# annualreport2002webnew.pdf   -  (207/590)
#
#  ['benchmarkfunds']
#  ['webmaster', 'mcsmum']
#  ['ITC', 'HDFC', 'ICICI']
#  ['HDFC Bank Ltd.', 'Castrol India Ltd.', 'Tata Power Company Ltd.', 'NIIT Ltd.', 'Hindalco Industries Ltd.', 'Dabur India Ltd.', 'MCS Ltd.', 'Cipla Ltd.', 'Nestle India Ltd.', 'Tata Chemicals Ltd.', 'Asian Paints Ltd.', 'Mahindra & Mahindra Ltd.', 'Bajaj Auto Ltd.', 'Mahanagar Telephone Nigam Ltd.', 'Grasim Industries Ltd.', 'Hindustan Petroleum Corporation Ltd.', 'ITC Ltd.']
#
# Call : None  -  Price : None
#
# IFB_Industries_Ltd_080814.pdf   -  (208/590)
#
#  ['ifbglobal']
#  ['dipak']
#  []
#  []
#
# Call : None  -  Price : None
#
# Akzo Nobel-Value Pick.pdf   -  (209/590)
#
#  ['rathi']
#  ['vivekgujrati', 'akprabhakar', 'PE ', 'shwetaprabhu']
#  ['AKZOINDIA']
#  []
#
# Call : Sell  -  Price : 1172.0
#
# India's economy_ How India got its funk _ The Economist.pdf   -  (210/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# lbs061812appendixG.pdf   -  (211/590)
#
#  ['NBIM']
#  ['Vatnar, John Tore']
#  []
#  []
#
# Call : None  -  Price : None
#
# Case_Study_8.pdf   -  (212/590)
#
#  ['Whiteshield Partners framing']
#  ['Lullit Jezequel']
#  []
#  []
#
# Call : None  -  Price : None
#
# India+Strategy-+The+Gold+Attack+-+Is+it+Strong+Enough.pdf   -  (213/590)
#
#  ['morganstanley']
#  ['morganstanley.research']
#  []
#  []
#
# Call : Sell  -  Price : 12.0
#
# GUJGA-20180511-MOSL-RU-PG008.pdf   -  (214/590)
#
#  ['MotilalOswal']
#  ['Abhinil.Dahiwale', 'Swarnendu.Bhushan']
#  ['GUJGA IN']
#  []
#
# Call : None  -  Price : None
#
# Vaibhav Global Ltd - Investor & Analyst Meet Invite - 26 June 2014.pdf   -  (215/590)
#
#  ['cdr-india']
#  ['bridget']
#  []
#  ['Vaibhav Global Ltd.']
#
# Call : None  -  Price : None
#
# Ambit Insights_27Apr2018.pdf   -  (216/590)
#
#  ['ambit']
#  ['Sajid Merchant']
#  ['AXSB IN', 'RALI IN', 'SI IN']
#  []
#
# Call : None  -  Price : None
#
# CPBrochure.pdf   -  (217/590)
#
#  ['indiacp']
#  ['info']
#  ['DLF', 'TRIDENT', 'JHS']
#  []
#
# Call : None  -  Price : None
#
# UPL 1QFY19 result update - 180731.pdf   -  (218/590)
#
#  ['antiquelimited']
#  ['prashant.bothra', 'manish.mahawar']
#  ['UPL', 'UPLL IN']
#  []
#
# Call : Buy  -  Price : 750.0
#
# EDELWEISS_FUND_INSIGHT_NOV-13-EDEL.pdf   -  (219/590)
#
#  ['edelweissfin']
#  ['sriram.velayudhan', 'yogesh.radke']
#  ['ONGC', 'IIB IN', 'HEXW IN', 'PEPL IN', 'SBIN', 'PEPL', 'GAIL IN', 'IDEA IN', 'ITC', 'PLNG IN', 'UNSP IN', 'SUNP IN', 'GPPV IN', 'NTPC', 'WLDL IN', 'Z IN', 'IDBI', 'BJAUT IN', 'HNDL IN', 'HTML IN', 'BHARTI IN', 'RIL IN', 'LT', 'HDFC', 'MSIL IN', 'PWGR IN', 'SIEM IN', 'YES IN', 'ICICI', 'GAIL', 'IDFC', 'IDEA', 'JSP IN', 'KMB IN', 'TATA IN', 'LT IN', 'FB IN', 'BOI IN', 'NMDC', 'VYSB IN', 'BHIN IN', 'MM IN', 'AXSB IN', 'PIDI IN', 'INFO IN', 'VOLT IN', 'EXID IN', 'MRF IN', 'SBIN IN', 'MRF']
#  ['United Spirits Ltd.', 'Lupin Ltd.', 'Prestige Estate Projects Ltd.', 'Bharti Infratel Ltd.', 'Tata Steel Ltd.', 'Mahindra & Mahindra Ltd.', 'The Federal Bank Ltd.', 'Westlife Development Ltd.', 'IndusInd Bank Ltd.', 'Bank Of India', 'Yes Bank Ltd.', 'Jindal Steel & Power Ltd.', 'Pidilite Industries Ltd.', 'Gujarat Pipavav Port Ltd.', 'HT Media Ltd.', 'MRF Ltd.', 'Reliance Industries Ltd.', 'Kotak Mahindra Bank Ltd.', 'Zee Entertainment Enterprises Ltd.', 'Voltas Ltd.', 'Maruti Suzuki India Ltd.', 'Axis Bank Ltd.', 'Infosys Ltd.', 'Larsen & Toubro Ltd.', 'Siemens Ltd.', 'GAIL (India) Ltd.']
#
# Call : None  -  Price : None
#
# Investor Aug-14.pdf   -  (220/590)
#
#  ['godrejproperties']
#  ['vikramr', 'kbolaria']
#  ['TOTAL']
#  []
#
# Call : None  -  Price : None
#
# Balkrishna Industries Limited - A R 2012-13.pdf   -  (221/590)
#
#  ['shareproservices']
#  ['sharepro']
#  ['ARVIND', 'AUSTRAL', 'ACC', 'ICICI', 'STAN', 'TOTAL', 'LT', 'HDFC', 'BALKRISHNA', 'TI']
#  ['Govind Rubber Ltd.']
#
# Call : None  -  Price : None
#
# iEnergy+Theni+Wind+farm+RAC.pdf   -  (222/590)
#
#  ['fitchratings']
#  ['bindu.menon', 'leslie.tan']
#  []
#  []
#
# Call : None  -  Price : None
#
# HDFC 1QFY16 Outlook.pdf   -  (223/590)
#
#  ['sparkcapital']
#  ['navin', 'abhinesh', 'nishant']
#  ['HDFC', 'TI', 'HDFC IN']
#  []
#
# Call : None  -  Price : None
#
# CJ July 2013.pdf   -  (224/590)
#
#  ['hotmail']
#  ['ansekhri', 'rcaavi']
#  ['GHCL', 'BPL']
#  ['Duncans Industries Ltd.', 'Escorts Ltd.', 'Jindal Saw Ltd.']
#
# Call : Buy  -  Price : 118.0
#
# US Generic - Mar14 .pdf   -  (225/590)
#
#  ['idfc']
#  ['santosh.fernandes']
#  ['IDFC', 'DRL']
#  []
#
# Call : Buy  -  Price : 35.0
#
# Jain_Irrigation_Systems_Ltd_1203121.pdf   -  (226/590)
#
#  ['jains']
#  ['jis|']
#  []
#  ['Jain Irrigation Systems Ltd.']
#
# Call : None  -  Price : None
#
# [Kotak] HCL Technologies, October 23, 2018.pdf   -  (227/590)
#
#  ['kotak']
#  ['sathishkumar', 'kotak.research', 'kawaljeet.saluja']
#  []
#  []
#
# Call : Buy  -  Price : 952.0
#
# CALCNTUT.pdf   -  (228/590)
#  ['Others']
#  ['Unknown']
#  ['PSB']
#  []
#
# Call : Sell  -  Price : 1.0
#
# Kotak UBS 270417.pdf   -  (229/590)
#
#  ['ubs']
#  ['ishank.kumar', 'vishal.goyal']
#  []
#  []
#
# Call : Buy  -  Price : 1050.0
#
# Beta Drugs Ltd.pdf   -  (230/590)
#
#  ['betadrugslimited']
#  ['info', 'ipo']
#  ['BETA']
#  []
#
# Call : None  -  Price : None
#
# Cyient Analyst day_final.pdf   -  (231/590)
#
#  ['sparkcapital']
#  ['aishwariya', 'srivathsan']
#  ['CYL IN', 'CYIENT']
#  ['Cyient Ltd.']
#
# Call : None  -  Price : None
#
# cummins oct 2014.pdf   -  (232/590)
#
#  ['ilfsindia']
#  ['devang.patel']
#  ['KKC IN', 'BHEL', 'LT']
#  []
#
# Call : Buy  -  Price : 12.0
#
# CSFEb15.pdf   -  (233/590)
#
#  ['credit-suisse']
#  [None]
#  ['IOB IN', 'NEST IN', 'DBL IN', 'BHIN IN', 'FCL', 'NH', 'IOB', 'HZ IN', 'DBL', 'SUNP IN', 'MSS IN', 'KSE']
#  ['Indian Overseas Bank']
#
# Call : Sell  -  Price : 18.0
#
# Table-1.pdf   -  (234/590)
#
#  ['Ace Equity']
#  ['NA']
#  ['DLF', 'IRB', 'DOLLAR']
#  []
#
# Call : None  -  Price : None
#
# IIFL-+Titan-Gold+standard-ADD.pdf   -  (235/590)
#
#  ['iif']
#  ['mitra', 'arnab.mitra']
#  ['IIFL', 'TTAN IN', 'JUBILANT', 'LOVABLE', 'TI', 'GKB']
#  []
#
# Call : Sell  -  Price : 2011.0
#
# ICNT-20151028-MOSL-RU-PG012.pdf   -  (236/590)
#
#  ['MotilalOswal']
#  ['kadambari.balachandran', 'Niket.Shah', 'Atul.Mehra', 'reports']
#  ['ICNT IN']
#  []
#
# Call : None  -  Price : None
#
# Vaibhav Global - Investor & Analyst meet presentation.pdf   -  (237/590)
#
#  ['cdr-india']
#  ['karl']
#  ['TI']
#  ['Vaibhav Global Ltd.']
#
# Call : None  -  Price : None
#
# INFDEVFC_20150909.pdf   -  (238/590)
#
#  ['plindia']
#  ['nitinkumar', 'priteshbumb']
#  ['HDFC', 'IDFC', 'ICICI']
#  []
#
# Call : Buy  -  Price : 2015.0
#
# Hester_8 Page Notice.pdf   -  (239/590)
#
#  ['cdslindia']
#  ['sharepro', 'scrutinizer', 'helpdesk.evoting', 'mail']
#  []
#  []
#
# Call : None  -  Price : None
#
# Centrum Wealth - L G  Balakrishnan  Bros  Ltd - Initiating Coverage - 30 June 2015.pdf   -  (240/590)
#
#  ['centrum']
#  ['investor.grievances', 'compliance']
#  ['LGBBROSLTD', 'SUPRAJIT', 'SETCO', 'CDSL']
#  []
#
# Call : Buy  -  Price : 30.0
#
# HDFC sec- Suzlon Energy (1QFY18)- A shock, though a positive one. Maintain BUY.pdf   -  (241/590)
#
#  ['hdfcsec']
#  ['ashutosh.mehta']
#  ['SUZLON', 'KEC', 'SUEL IN', 'TOTAL', 'HDFC']
#  []
#
# Call : Sell  -  Price : 25.0
#
# Westlife Development - Q3FY18 Result Update- JMFL.pdf   -  (242/590)
#
#  ['jmfl']
#  ['ruchir.jhunjhunwala', 'sunny.shah', 'richard.liu', 'jmfinancial.research', 'vicky.punjabi']
#  []
#  []
#
# Call : Buy  -  Price : 400.0
#
# find-information.pdf   -  (243/590)
#
#  ['idea']
#  ['study2008']
#  ['ACC', 'IDEA', 'TAKE']
#  []
#
# Call : None  -  Price : None
#
# 2014-02-05 SUPE.BO (Anand Rathi S) Suprajit Engineering - Growth despite slowdown in the home OEM market%3B Buy.65684159 (2).pdf   -  (244/590)
#
#  ['rathi']
#  ['girishsolanki']
#  ['SEL IN']
#  []
#
# Call : Buy  -  Price : 1.0
#
# Ambit_Petronet LNG_Company Insight_Whats the plan for cash_20Nov2017.pdf   -  (245/590)
#
#  ['ambit']
#  ['Ritesh Gupta']
#  ['ONGC', 'MGL', 'GSPL', 'GAIL', 'PLNG IN', 'IGL', 'IOC']
#  []
#
# Call : Buy  -  Price : 300.0
#
# Tree_House_Education_BIRI_IPO_Report.pdf   -  (246/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# JM Financial- NTPC - 1Q18 Core RoE at 19%; High commercialisation cycle begins.pdf   -  (247/590)
#
#  ['jmfl']
#  ['subhadip.mitra', 'jmfinancial.research', 'ruchir.jhunjhunwala', 'sunny.shah']
#  ['NTPC']
#  []
#
# Call : Buy  -  Price : 2.0
#
# JSW-20170123-MOSL-RU-PG006.pdf   -  (248/590)
#
#  ['motilaloswal']
#  ['Varun.kumar']
#  ['JSW IN', 'LT']
#  []
#
# Call : None  -  Price : None
#
# Coromandel Conference_Call_106395_20160727.pdf   -  (249/590)
#
#  ['Others']
#  ['Punit Jani']
#  []
#  []
#
# Call : None  -  Price : None
#
# TMKN 2QFY18 Outlook Review.pdf   -  (250/590)
#
#  ['sparkcapital']
#  ['rseshan', 'mukesh']
#  ['TMKN IN', 'STAN', 'TOTAL', 'TIMKEN', 'TI']
#  []
#
# Call : Buy  -  Price : 860.0
#
# India Banks Undoing Financial Repression Structural Reset of Economics 3-Sep'14.pdf   -  (251/590)
#
#  ['sparkcapital']
#  ['jyothikumar', 'navin', 'gautam', 'abhinesh']
#  ['ICICI', 'PNB', 'IOB', 'SBIN', 'CUB', 'HDFC']
#  []
#
# Call : None  -  Price : None
#
# ECO-RBI_POLICY-20180604-MOSL-ES-PG006.pdf   -  (252/590)
#
#  ['motilaloswal']
#  ['Nikhil.Gupta', 'Rahul.Agrawal']
#  []
#  []
#
# Call : None  -  Price : None
#
# IGL.pdf   -  (253/590)
#
#  ['MotilalOswal']
#  ['Abhinil.Dahiwale', 'Swarnendu.Bhushan']
#  ['IGL IN', 'STAN', 'GAIL', 'IGL', 'HDFC']
#  []
#
# Call : Buy  -  Price : 44.0
#
# Jefferies- India Banks Group Pricing of Credit 101.pdf   -  (254/590)
#
#  ['jefferies']
#  ['nkarfa']
#  []
#  []
#
# Call : Sell  -  Price : 12.0
#
# 5April 2018_India_Daily.pdf   -  (255/590)
#
#  ['kotak']
#  ['Kotak Institutional Equities']
#  ['PNB', 'IDBI', 'RCOM', 'HDFC', 'TECHM IN', 'PNB IN', 'ICICI', 'HDIL IN', 'HDIL', 'UNBK IN', 'RCOM IN', 'BOI IN', 'AL IN', 'GCPL IN', 'INFO IN', 'IDBI IN', 'TECHM']
#  []
#
# Call : Buy  -  Price : 2.0
#
# AMP - 180403.pdf   -  (256/590)
#
#  ['antiquelimited']
#  ['rohit.natarajan', 'prashant.bothra', 'manish.mahawar']
#  ['ONGC', 'PNB', 'IRB', 'SUBEX', 'ITC', 'BHEL', 'BEML', 'NCC', 'LT', 'DLF', 'MOIL', 'UPL', 'TCS', 'HDFC', 'ICICI', 'M&M', 'GAIL', 'NJCC IN', 'NBCC', 'DAGRI IN', 'OIL', 'ICRA', 'SAIL', 'NMDC', 'ACC', 'KEC', 'PTC', 'ABB', 'BPCL']
#  ['State Bank Of India', 'Punjab National Bank', 'Canara Bank', 'NCC Ltd.']
#
# Call : Buy  -  Price : 700.0
#
# BOAML-StagnatingIndicators.pdf   -  (257/590)
#
#  ['baml']
#  ['indranil.sengupta']
#  ['MEP']
#  []
#
# Call : None  -  Price : None
#
# TIl Q1 2015 reults.pdf   -  (258/590)
#
#  ['Others']
#  ['icraadmin']
#  ['TOTAL', 'TIL', 'TI', 'GSL']
#  []
#
# Call : None  -  Price : None
#
# Adani_Power_Q1FY18_results.pdf   -  (259/590)
#
#  ['icicisecurities']
#  ['apoorva.bahadur', 'prakash.goel']
#  ['ICICI']
#  []
#
# Call : Sell  -  Price : 19.0
#
# 1345798948346-a (2).pdf   -  (260/590)
#
#  ['Others']
#  ['1890']
#  []
#  []
#
# Call : None  -  Price : None
#
# Full Report of Future of Mobile Value Added Services (VAS) in India.pdf   -  (261/590)
#
#  ['bdaconnect']
#  ['kosnik', 'mohitgundecha', 'mohitsg', 'kunal.bajaj', 'contactus']
#  ['MTNL', 'LML', 'IDEA']
#  []
#
# Call : Sell  -  Price : 2007.0
#
# IndusInd_Bank_-_4QFY18_-_HDFC_sec.pdf   -  (262/590)
#
#  ['hdfcsec']
#  ['darpin.shah', 'Pranav.gupta']
#  ['IIB IN', 'ICICI', 'SBIN', 'CUB', 'HDFC']
#  []
#
# Call : None  -  Price : None
#
# Avant Garde Wealth Mgmt - Quarterly letter - 1309.pdf   -  (263/590)
#
#  ['National Stock Exchange']
#  ['NA']
#  []
#  []
#
# Call : Sell  -  Price : 500.0
#
# the economic times - gfl - wind turbines - amdavad - 27102007.pdf   -  (264/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# India_Opportunities_Real_Estate_Fund_March12.pdf   -  (265/590)
#
#  ['SCnicll']
#  ['#iX']
#  ['ICICI']
#  []
#
# ...
#
# banks_db_191011.pdf   -  (507/590)
#
#  ['db']
#  ['abhay.laijawala', 'abhishek.saraf']
#  ['ACC', 'ICICI', 'NH', 'IRB', 'ITC', 'DLF', 'NHPC', 'HDFC', 'NTPC', 'MIC', 'TI']
#  []
#
# Call : Buy  -  Price : 2011.0
#
# HDFCB-RR-260417.pdf   -  (508/590)
#
#  ['idbicapital']
#  ['pravin.mule', 'ravikant.bhat', 'dealing']
#  ['ACC', 'HDFC', 'IDBI']
#  []
#
# Call : None  -  Price : None
#
# Deutsche Bank- Motherson Sumi Systems-eRrgrp- NDR takeaways – focus on technology will drive business growth.pdf   -  (509/590)
#
#  ['db']
#  ['amyn.pirani', 'srini.rao']
#  ['MSS IN']
#  []
#
# Call : Buy  -  Price : None
#
# BNK_090215_195059.pdf   -  (510/590)
#
#  ['bksec']
#  ['ranjit.cirumalla']
#  ['PVR', 'GFLC IN', 'SRF', 'GFL']
#  []
#
# Call : Buy  -  Price : None
#
# Corporate%20Governance.pdf   -  (511/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# Affordable_Housing_in_India_2012.pdf   -  (512/590)
#
#  ['ap']
#  ['ashutosh.limaye', 'subhankar.mitra', 'somdutta.dey', 'mitali.nanavaty', 'himadri.mayank']
#  ['BANG']
#  []
#
# Call : Buy  -  Price : 10.0
#
# Union Bank of India - 1QFY18 Earnings Report - Aug 17.pdf   -  (513/590)
#
#  ['bksec']
#  ['anand.dama', 'jai.mundhra']
#  []
#  []
#
# Call : None  -  Price : 1.0
#
# IndusInd BankQ3FY14 RU.pdf   -  (514/590)
#
#  ['uljk']
#  ['Siddharth.purohit']
#  []
#  []
#
# Call : Buy  -  Price : 520.0
#
# IBU_May03.pdf   -  (515/590)
#
#  ['genesispr']
#  ['cdalton']
#  []
#  []
#
# Call : None  -  Price : None
#
# Havells Unaudited Financial Results Q3FY14.pdf   -  (516/590)
#
#  ['havells']
#  ['investors']
#  ['HAVELLS']
#  []
#
# Call : None  -  Price : None
#
# Exide_4QFY16 Results Review Final.pdf   -  (517/590)
#
#  ['sparkcapital']
#  ['rseshan', 'mukesh']
#  ['EXID IN', 'TOTAL']
#  []
#
# Call : Sell  -  Price : 22.0
#
# dp28245.pdf   -  (518/590)
#
#  ['kotak']
#  ['Administrator']
#  ['FACT', 'PREMIER', 'TOTAL', 'ITC', 'CDSL', 'VASA', 'GRASIM', 'NTPC', 'GLOBAL', 'SPIC', 'STER', 'GRASIM IN', 'OCL IN', 'MANGALAM', 'TRF', 'NCL IN', 'OCL', 'DLF', 'ATUL', 'TRIVENI', 'CHI', 'MEGH', 'MIC', 'CRISIL', 'BIL', 'CONTI', 'SAIL', 'HINDALCO', 'THERMAX', 'TI']
#  ['TRF Ltd.', 'Elecon Engineering Company Ltd.', 'ITC Ltd.']
#
# Call : Sell  -  Price : 10.0
#
# Ambit Results Insights_22Jan2018.pdf   -  (519/590)
#
#  ['ambit']
#  ['Sharoz Hussain']
#  ['APNT IN', 'HAVL IN', 'RALI IN']
#  []
#
# Call : Sell  -  Price : 960.0
#
# EDELWEISS_FUND_INSIGHT_JAN-14-EDEL.pdf   -  (520/590)
#
#  ['edelweissfin']
#  ['sriram.velayudhan', 'yogesh.radke']
#  ['ONGC', 'IIB IN', 'PNB', 'SBIN', 'IDEA IN', 'BOB IN', 'OFSS', 'ITC', 'UNSP IN', 'DRRD IN', 'MMFS IN', 'BHEL', 'MSS IN', 'NTPC', 'Z IN', 'IDBI', 'OFSS IN', 'BJAUT IN', 'TTAN IN', 'JKBK IN', 'LT', 'RIL IN', 'BHARTI IN', 'DLF', 'AMRJ IN', 'ARBP IN', 'HDFC', 'WPRO IN', 'TCS', 'MSIL IN', 'PNB IN', 'PWGR IN', 'SKF IN', 'SIEM IN', 'TTMT IN', 'JUST IN', 'ICICI', 'JSTL IN', 'M&M', 'GAIL', 'IDFC', 'IDEA', 'JSP IN', 'OINL IN', 'FB IN', 'LT IN', 'TATA IN', 'NMDC', 'ACC', 'AXSB IN', 'PIDI IN', 'APTY IN', 'INFO IN', 'EXID IN', 'STR IN', 'TRP IN', 'BPCL', 'SBIN IN', 'BDE IN']
#  ['Lupin Ltd.', 'SKF India Ltd.', 'The Jammu & Kashmir Bank Ltd.', 'Wipro Ltd.', 'The Federal Bank Ltd.', 'IndusInd Bank Ltd.', 'Blue Dart Express Ltd.', 'Tata Motors Ltd.', 'Jindal Steel & Power Ltd.', 'Pidilite Industries Ltd.', 'Apollo Tyres Ltd.', 'State Bank Of India', 'Exide Industries Ltd.', 'Reliance Industries Ltd.', 'Zee Entertainment Enterprises Ltd.', 'Maruti Suzuki India Ltd.', 'Axis Bank Ltd.', 'Bank Of Baroda', 'Infosys Ltd.', 'Punjab National Bank', 'JSW Steel Ltd.', 'Larsen & Toubro Ltd.', 'Torrent Pharmaceuticals Ltd.', 'Siemens Ltd.']
#
# Call : None  -  Price : None
#
# 0810ifrsrealestate.pdf   -  (521/590)
#
#  ['deloitte']
#  ['nholtz']
#  []
#  []
#
# Call : None  -  Price : None
#
# Earnings-Presentation-Q3-2013-14.pdf   -  (522/590)
#
#  ['thinksoftglobal']
#  ['dpingle', 'vaidyanathan.n']
#  []
#  []
#
# Call : None  -  Price : None
#
# AMP - 180416.pdf   -  (523/590)
#
#  ['antiquelimited']
#  ['kunal.randeria', 'digant.haria', 'bhavik.mehta']
#  ['ONGC', 'PNB', 'IRB', 'ITC', 'DHFL', 'BHEL', 'CANBK', 'BEML', 'TVSMOTOR', 'SIEMENS', 'NCC', 'GRUH', 'GRHF IN', 'LT', 'MOIL', 'UPL', 'ESCORTS', 'CHENNPETRO', 'TCS', 'HDFC', 'DISHTV', 'ICICI', 'M&M', 'GAIL', 'BALKRISIND', 'NBCC', 'OIL', 'ICRA', 'SAIL', 'MINDTREE', 'NMDC', 'WOCKPHARMA', 'ACC', 'KEC', 'MGL', 'BEL', 'PTC', 'ABB', 'JPASSOCIAT', 'BPCL', 'TECHM']
#  ['Canara Bank', 'State Bank Of India', 'NCC Ltd.', 'Punjab National Bank']
#
# Call : Buy  -  Price : 547.0
#
# IDFC Securities- Sector update- Indian Financials - An On-ground Guide to Financial inclusion.pdf   -  (524/590)
#
#  ['idfc']
#  ['santosh.fernandes']
#  ['IDFC']
#  []
#
# Call : Sell  -  Price : 200.0
#
# Dissertation_RamkumarK.pdf   -  (525/590)
#
#  ['gmail']
#  ['Ramkumar.Kft09', 'Ram.kriss']
#  ['CRISIL']
#  []
#
# Call : Sell  -  Price : 8.0
#
# ICICI Direct- Result Update - India Cement (Buy) errclub Decline in power & fuel cost drives margins....pdf   -  (526/590)
#
#  ['icicisecurities']
#  ['rashes.shah', 'devang.bhatt', 'pankaj.pandey', 'research']
#  ['ACC', 'SFCL', 'ICICI', 'ICL']
#  []
#
# Call : Buy  -  Price : 105.0
#
# TTMT-20181009-MOSL-CU-PG006.pdf   -  (527/590)
#
#  ['MotilalOswal']
#  ['Deep.S', 'Jinesh', 'Suneeta.Kamath']
#  ['TTMT IN']
#  []
#
# Call : Buy  -  Price : 11.0
#
# 07102014115602MMDR Act 1957_10052012 (2).pdf   -  (528/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# Aarti concall transcript dec 2016.pdf   -  (529/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# Embracing Innovation Driving Growth Across Healthcare Continuum_Medcon_2017.pdf   -  (530/590)
#
#  [' assocham']
#  ['d.s.rawat', 'lifesciences']
#  ['NH']
#  []
#
# Call : None  -  Price : None
#
# Britannia_CallUpdate_050115.pdf   -  (531/590)
#
#  ['indiainfoline']
#  ['research']
#  ['BRITANNIA', 'IIFL', 'GLOBAL']
#  []
#
# Call : Buy  -  Price : 104.0
#
# Bits---pieces-5-Feb-2010---Golden-Tiger.pdf   -  (532/590)
#  ['sundarambnpparibas']
#  ['balajiv']
#  ['FACT', 'MAKE', 'ACC', 'PREMIER', 'ICICI', 'HAL', 'SUMIT', 'PEL', 'CHI', 'HDFC', 'NTPC', 'BHEL', 'TI']
#  []
#
# Call : Buy  -  Price : 2010.0
#
# brent wti crude wxplained.pdf   -  (533/590)
#
#  ['Others']
#  ['NA']
#  ['MAKE']
#  []
#
# Call : Buy  -  Price : 5.0
#
# BHEL-20150303-MOSL-CU-PG018.pdf   -  (534/590)
#
#  ['motilaloswal']
#  ['reports', 'kadambari.balachandran', 'Shah(Amit.Shah', 'Agarwal(AgarwalS', 'anosh.Koppikar']
#  ['BHEL IN', 'BHEL', 'NTPC']
#  []
#
# Call : Buy  -  Price : 320.0
#
# Indian Gas Sector - Citi .pdf   -  (535/590)
#
#  ['citi']
#  ['saurabh.handa', 'sohini1.banerjee']
#  ['GSPL', 'GAIL']
#  []
#
# Call : Buy  -  Price : 21.0
#
# DELTA-20140918-MOSL-SL-PG032.pdf   -  (536/590)
#
#  ['motilaloswal']
#  ['reports', 'kadambari.balachandran', 'Niket.Shah', 'Email:anosh.Koppikar', 'Atul.Mehra']
#  ['AMBER', 'MDL']
#  []
#
# Call : Buy  -  Price : 27.0
#
# GlobalDirectory.pdf   -  (537/590)
#
#  ['worldbank']
#  ['Myoung3']
#  ['TI']
#  []
#
# Call : None  -  Price : None
#
# WHat+i+learned+-+Ridham+I+-+180612+-+Morgan.pdf   -  (538/590)
#
#  ['morganstanley']
#  ['Ridham.Desai']
#  []
#  []
#
# Call : Sell  -  Price : 12.0
#
# Pocket-Guide-for-Digital-Payments.pdf   -  (539/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# KPMG-Flash-News-JSW-Energy-Limited.pdf   -  (540/590)
#
#  ['Others']
#  ['KPMG']
#  ['DLF']
#  []
#
# Call : Sell  -  Price : 3.0
#
# India Cement note UBS Q1 2017.pdf   -  (541/590)
#
#  ['ubs']
#  ['william.vanderpump', 'hemant.bakhru']
#  ['KCP', 'ACC']
#  ['ACC Ltd.', 'KCP Ltd.']
#
# Call : Buy  -  Price : 2017.0
#
# IT services UBS.pdf   -  (542/590)
#
#  ['ubs']
#  ['diviya.nagarajan']
#  ['TCS', 'INFY']
#  ['Wipro Ltd.', 'Tata Consultancy Services Ltd.']
#
# Call : Buy  -  Price : None
#
# petronet.pdf   -  (543/590)
#
#  ['hdfcsec']
#  ['satish.mishra', 'deepak.kolhe']
#  ['ONGC', 'TOTAL', 'BPCL', 'PLNG IN', 'LT', 'OIL', 'HDFC', 'PETRONET']
#  []
#
# Call : Sell  -  Price : 435.0
#
# TTKPT-RR-170113.pdf   -  (544/590)
#
#  ['idbicapital']
#  ['sonam.udasi', 'dealing', 'arun.baid']
#  ['IDBI']
#  ['TTK Prestige Ltd.']
#
# Call : None  -  Price : None
#
# Textile Axis report.pdf   -  (545/590)
#
#  ['axissecurities']
#  ['akhand.singh']
#  ['ACML IN', 'KPR IN']
#  ['Siyaram Silk Mills Ltd.']
#
# Call : Sell  -  Price : 9000.0
#
# expertprint.pdf   -  (546/590)
#
#  ['Others']
#  ['NA']
#  []
#  []
#
# Call : None  -  Price : None
#
# Va Tech Wabag - 3QFY18 Result Update- PL India.pdf   -  (547/590)
#
#  ['plindia']
#  ['rsreesankar', 'keyurpandya']
#  []
#  []
#
# Call : Sell  -  Price : 628.0
#
# [Kotak] Godrej Properties, January 29, 2019.pdf   -  (548/590)
#
#  ['kotak']
#  ['kotak.research', 'samrat.verma', 'murtuza.arsiwalla']
#  []
#  []
#
# Call : Buy  -  Price : 1747.0
#
# Kewal Kiran Analsyt Ppt Q4  FY2011.pdf   -  (549/590)
#
#  ['Others']
#  ['RippleWave-Rahul']
#  []
#  []
#
# Call : None  -  Price : None
#
# India+Banks+-+Discom+Restructuring+140312.pdf   -  (550/590)
#
#  ['barcap']
#  ['jatin.mamtani', 'nikhil.poddar', 'anish.tawakley']
#  ['ICICI', 'PNB', 'HDFC', 'BSI']
#  ['Canara Bank', 'Standard Chartered PLC', 'Punjab National Bank']
#
# Call : Sell  -  Price : 60.0
#
# UTCEM-20180425-MOSL-RU-PG008.pdf   -  (551/590)
#
#  ['motilaloswal']
#  ['Pradnya.Ganar', 'Abhishek.Ghosh']
#  ['UTCEM IN']
#  []
#
# Call : None  -  Price : None
#
# MAGMBFeb11.pdf   -  (552/590)
#
#  ['enam']
#  ['namesh.chhangani', 'praveen.agarwal', 'siddharth.goel']
#  ['LT']
#  []
#
# Call : Sell  -  Price : 86.0
#
# make-consolidated-january19-2013-to-march31-2014.pdf   -  (553/590)
#
#  ['Others']
#  ['NA']
#  ['TOTAL', 'MARICO']
#  []
#
# Call : None  -  Price : None
#
# Balkrishna Industries. - Revenue recovery and cost advantage make a good combination.pdf   -  (554/590)
#
#  ['credit-suisse']
#  ['vikash.patwari', 'anantha.narayan']
#  ['BSL', 'MRF', 'MIC']
#  []
#
# Call : Sell  -  Price : 12.0
#
# 2003_Issue1.pdf   -  (555/590)
#
#  ['raytheon']
#  ['debra']
#  ['MIC', 'TI', 'STAN']
#  []
#
# Call : None  -  Price : None
#
# Escorts Ltd -Quarter ending March 2014 - Result Update - Accumulate.pdf   -  (556/590)
#
#  ['qsmail']
#  ['shaukat']
#  ['TOTAL', 'ESC IN']
#  []
#
# Call : None  -  Price : None
#
# CompanyValuationPPT.pdf   -  (557/590)
#
#  ['Others']
#  ['Raghu Rau']
#  ['TI']
#  []
#
# Call : None  -  Price : None
#
# conf axis nov13.pdf   -  (558/590)
#
#  ['axiscap']
#  ['nandan.chakraborty']
#  ['ONGC', 'M&M', 'RCOM', 'PVR', 'LT', 'ITC', 'ZEEL', 'CESC', 'HDFC', 'CRISIL']
#  []
#
# Call : Buy  -  Price : 2013.0
#
# Indian Road Sector_ASBL & ITNL Initiation_Sept 1 2014.pdf   -  (559/590)
#
#  ['sparkcapital']
#  ['bharanidhar']
#  ['ILFT IN', 'CCCL', 'NCC', 'ASBL IN', 'NH', 'IRB', 'IRB IN']
#  []
#
# Call : Buy  -  Price : None
#
# document-807204990.pdf   -  (560/590)
#
#  ['credit-suisse']
#  [None]
#  []
#  []
#
# Call : Sell  -  Price : 2014.0
#
# Corporate Presentation - January 2015.pdf   -  (561/590)
#
#  ['Company']
#  ['Munishpc']
#  ['LT']
#  []
#
# Call : None  -  Price : None
#
# ICICI Prudential Life Insurance (ICIR.NS)- Correction- 10 Focus Charts – MS.pdf   -  (562/590)
#
#  ['morganstanley']
#  ['Subramanian.Iyer', 'Sumeet.Kariwala', 'Rahul.Gupta1', 'Anil.Agarwal']
#  ['RBL', 'ICICI', 'PNB', 'TOTAL', 'IDFC', 'HDFC']
#  ['LIC Housing Finance Ltd.', 'Canara Bank', 'Edelweiss Financial Services Ltd.', 'Punjab National Bank']
#
# Call : Buy  -  Price : 1.0
#
# time-rhpfinal.pdf   -  (563/590)
#
#  ['30%']
#  ['Interest  ', 'henam', 'Saurabh.bhatiani']
#  ['TOTAL', 'ITC', 'CDSL', 'STER', 'IDBI', 'TIL', 'TTL', 'HDFC', 'ICICI', 'TOTAL IN', 'CONTI', 'ACE', 'BPL', 'GSL', 'ACC', 'PDPL', 'ABB', 'TI']
#  []
#
# Call : Sell  -  Price : 10.0
#
# Vodafone Idea (VODA.BO) - 2QFY19 results - Citi.pdf   -  (564/590)
#
#  ['citi']
#  ['vijit.jain']
#  []
#  []
#
# Call : Buy  -  Price : 12.0
#
# Advancing-Financial-Inclusion-in-India.pdf   -  (565/590)
#
#  ['brookingsindia']
#  ['sgakhar', 'sravi']
#  []
#  []
#
# Call : None  -  Price : None
#
# LICHF_310314.pdf   -  (566/590)
#
#  ['indiainfoline']
#  ['research']
#  ['LICHSGFIN', 'LICHF IN', 'NH', 'IIFL']
#  []
#
# Call : Buy  -  Price : 2014.0
#
# MANDHANA INDUSTRIES LIMITED-06-10-2016.pdf   -  (567/590)
#
#  ['careratings']
#  [None]
#  ['MANDHANA']
#  []
#
# Call : None  -  Price : None
#
# dip2.pdf   -  (568/590)
#
#  ['sebi']
#  ['neelamb', 'ushar']
#  ['HDFC', 'CRISIL']
#  []
#
# Call : None  -  Price : None
#
# avanthapower.pdf   -  (569/590)
#
#  ['enam']
#  ['axbmbd', 'complaints', 'apil.ipo', 'investors.cgmib', 'kmccredressal']
#  ['FACT', 'ACC', 'BIL', 'ICICI', 'TAKE', 'GAIL', 'TOTAL', 'IDFC', 'KSK', 'CDSL', 'SRF', 'BHEL', 'IEX', 'NTPC', 'MCL', 'BPL']
#  ['Corporation Bank', 'IDFC Ltd.', 'Allahabad Bank']
#
# Call : Sell  -  Price : 10.0
#
# JSW Steel Q4FY17 - Result Update - Axis Direct - 25052017_25-05-2017_11.pdf   -  (570/590)
#
#  ['axissecurities']
#  ['pankaj.bobade', 'poonam.darade']
#  []
#  []
#
# Call : Buy  -  Price : 263.0
#
# Tourism Finance Corp - Stock Note - 120118.pdf   -  (571/590)
#
#  ['hdfcsec']
#  ['atul.karwa']
#  ['TOTAL', 'TFCI IN', 'TFCILTD', 'HDFC', 'IFCI']
#  []
#
# Call : None  -  Price : None
#
# iifl - strategy - 2014 outlook - 20140102_08_57_04.pdf   -  (572/590)
#
#  ['iiflcap']
#  ['nemkumar']
#  ['ICICI', 'M&M', 'IIFL', 'ITC', 'HDFC']
#  []
#
# Call : Buy  -  Price : 2014.0
#
# [Kotak] Karur Vysya Bank, July 25, 2018.pdf   -  (573/590)
#
#  ['kotak']
#  ['Shrey.singh', 'nischint.chawathe', 'kotak.research', 'mb.mahesh', 'dipanjan.ghosh']
#  []
#  []
#
# Call : Buy  -  Price : 110.0
#
# MACA-20150212-MOSL-SLU-PG010.pdf   -  (574/590)
#
#  ['motilaloswal']
#  ['kadambari.balachandran', 'anosh.Koppikar', 'Jinesh', 'reports']
#  ['AMBER']
#  []
#
# Call : None  -  Price : None
#
# INFOSYS - ANTIQUE.pdf   -  (575/590)
#
#  ['antiquelimited']
#  ['omkar.hadkar', 'govind.agarwal']
#  ['INFO IN']
#  []
#
# Call : Buy  -  Price : 915.0
#
# Elgi Equipments_IC_Spark Capital_23.03.2015.pdf   -  (576/590)
#
#  ['sparkcapital']
#  ['raghavan', 'ravi']
#  ['ELEQ IN']
#  []
#
# Call : Buy  -  Price : 204.0
#
# ChinaSec_24May06.pdf   -  (577/590)
#
#  ['fitchratings']
#  ['joanna.dong', 'wit.solberg', 'kevin.stephenson', 'henry.hung', 'jet.zhou']
#  []
#  []
#
# Call : None  -  Price : None
#
# United Breweries Q4FY18 Result Update - Emkay.pdf   -  (578/590)
#
#  ['emkayglobal']
#  ['ashit.desai', 'dhiraj.mistry']
#  ['ACC', 'UBBL IN']
#  ['Emkay Global Financial Services Ltd.']
#
# Call : Buy  -  Price : 12.0
#
# Banswara Syntex Ltd.-Results.pdf   -  (579/590)
#
#  ['banswarasyntex']
#  ['info', 'jkjain', 'kjaln']
#  ['STAN']
#  ['BSE Ltd.']
#
# Call : None  -  Price : None
#
# Gujarat_Fluorochemicals_Ltd_100315.pdf   -  (580/590)
#
#  ['Others']
#  ['NA']
#  ['GFL']
#  []
#
# Call : None  -  Price : None
#
# JM Financial - Textiles Sector - Cotton Sheet US Market Share Dips In May'16 (Sector Update).pdf   -  (581/590)
#  ['jmfl']
#  ['ashutosh.somani', 'nitin.agarwala']
#  []
#  []
#
# Call : None  -  Price : None
#
# HDFC Securities 16-May-16.pdf   -  (582/590)
#
#  ['hdfcsec']
#  ['abdul.karim', 'hdfcsecretailresearch']
#  ['HDFC']
#  []
#
# Call : None  -  Price : None
#
# HDFC+Warrants.pdf   -  (583/590)
#
#  ['nirmalbang']
#  ['vishal.jajoo']
#  ['HDFC', 'HDFC IN']
#  []
#
# Call : Buy  -  Price : 2008.0
#
# BATINDIA_20130729.pdf   -  (584/590)
#
#  ['nomura']
#  ['manish.jain', 'anup.sudhendranath']
#  ['NEST IN', 'CLGT IN', 'GCPL IN', 'HUVR IN', 'DABUR', 'APNT IN', 'TTAN IN', 'LT', 'MRCO IN', 'DABUR IN', 'ITC', 'UNSP IN', 'SKB IN', 'ITC IN', 'JUBI IN', 'BATA IN', 'HMN IN']
#  []
#
# Call : Buy  -  Price : 990.0
#
# FIEM Industries - IC - Centrum - 27.03.14.pdf   -  (585/590)
#
#  ['centrum']
#  ['compliance', 'investor.grievances', 'ajay.shethiya']
#  ['M&M', 'CDSL', 'NTL', 'MCX', 'MIC', 'FIEM IN']
#  []
#
# Call : Buy  -  Price : 545.0
#
# ANewParadigmforManagingforShareholderValue.pdf   -  (586/590)
#
#  ['asseteconomics']
#  ['john.j.ballow', 'michael.j.molnar', 'roland.burgman', 'goran.roos']
#  ['TI']
#  []
#
# Call : Sell  -  Price : 7.0
#
# TEL-20180108-MOSL-SU-PG006.pdf   -  (587/590)
#
#  ['motilaloswal']
#  ['Hafeez.Patel', 'Aliasgar.Shakir']
#  []
#  []
#
# Call : Buy  -  Price : 48.0
#
# Titan - SELL - CLSA.pdf   -  (588/590)
#
#  ['www.clsa.com']
#  ['vivek.maheshwari']
#  ['TI']
#  []
#
# Call : Sell  -  Price : 18.0
#
# BHEL-2QFY16 Review.pdf   -  (589/590)
#
#  ['sparkcapital']
#  ['raghavan', 'ravi']
#  ['BHEL', 'BHEL IN']
#  []
#
# Call : Sell  -  Price : 137.0
#
# ARVND-20150806-MOSL-RU-PG014.pdf   -  (590/590)
#
#  ['MotilalOswal']
#  ['kadambari.balachandran', 'Niket.Shah', 'Atul.Mehra', 'reports']
#  ['ARVND IN', 'ARVIND']
#  []
#
# Call : Buy  -  Price : 340.0

# %%
df
# Out:
#                                                   file     source company  \
# 0                                 JPM_022014_14225.pdf         [jpmorgan]
# 1    Deep Industries Ltd - Award of Hiring of Integ...   [deepindustrtes]
# 2       Industry-Map-of-the-Precious-Metals-Sector.pdf           [Others]
# 3    Ambit India Access_Pre-Budget conference call ...     [ambitcapital]
# 4          ThinkSoft-Corporate-Presentation-Mar-12.pdf  [thinksoftglobal]
# ..                                                 ...                ...
# 585     ANewParadigmforManagingforShareholderValue.pdf   [asseteconomics]
# 586                     TEL-20180108-MOSL-SU-PG006.pdf     [motilaloswal]
# 587                            Titan - SELL - CLSA.pdf     [www.clsa.com]
# 588                             BHEL-2QFY16 Review.pdf     [sparkcapital]
# 589                   ARVND-20150806-MOSL-RU-PG014.pdf     [MotilalOswal]
#
#                                                authors     company symbols  \
# 0      [deepika.mundra, sumit.x.kishore, boris.cw.kan]    [BHEL, KEC, ABB]
# 1                                               [info]                  []
# 2                                               [john]                  []
# 3                                               [None]                  []
# 4                            [dpingle, vaidyanathan.n]             [ICICI]
# ..                                                 ...                 ...
# 585  [john.j.ballow, michael.j.molnar, roland.burgm...                [TI]
# 586                    [Hafeez.Patel, Aliasgar.Shakir]                  []
# 587                                 [vivek.maheshwari]                [TI]
# 588                                   [raghavan, ravi]     [BHEL, BHEL IN]
# 589  [kadambari.balachandran, Niket.Shah, Atul.Mehr...  [ARVND IN, ARVIND]
#
#                                          company names trade call  \
# 0    [Apar Industries Ltd., Triveni Turbine Ltd., B...       Sell
# 1                                                   []       None
# 2                                                   []       None
# 3                                                   []       None
# 4                                                   []       None
# ..                                                 ...        ...
# 585                                                 []       Sell
# 586                                                 []        Buy
# 587                                                 []       Sell
# 588                                                 []       Sell
# 589                                                 []        Buy
#
#      target price                                  possible sources
# 0            20.0                         [jpmorgan, Company data.]
# 1             NaN                                  [deepindustrtes]
# 2             NaN                                                []
# 3             NaN                 [ambitpte, ambitcapital, panmure]
# 4             NaN  [christensenir, thinksoftglobal, NASSCOM Report]
# ..            ...                                               ...
# 585           7.0                 [asseteconomics, accenture, Inc.]
# 586          48.0                           [motilaloswal, Company]
# 587          18.0                              [clsa, www.clsa.com]
# 588         137.0                                    [sparkcapital]
# 589         340.0                [MotilalOswal, motilaloswal, MOSL]
#
# [590 rows x 8 columns]

# %%
df.to_csv('pdf_extracted_info.csv')

# %%
file_list[261]
# Out:
# 'IndusInd_Bank_-_4QFY18_-_HDFC_sec.pdf'

# %% [markdown]
# # Some Unsuccessful attemps

# %%
# extract text from text layout of pdfminer 


from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer, LTChar,LTLine,LAParams
Extract_Data=[]
for PDF_file in file_list[:3]:
       for page_layout in extract_pages(source_path+PDF_file):
            print(PDF_file)
            for element in page_layout:
                print(element)
                if isinstance(element, LTTextContainer):
                    for text_line in element:
                        for character in text_line:
                            if isinstance(character, LTChar):
                                Font_size=character.size
                    Extract_Data.append([Font_size,(element.get_text())])

# %%
## pdf image extraction and ocr on the extracted image

def process_images_ocr(file_list):

    import fitz
    import pytesseract
    from collections import defaultdict

    imgtext_corpus = defaultdict(set)

    for file in file_list:

        print(file)
        doc = fitz.open(source_path+file)
        print(len(doc))

        pages_to_scan = [0]
        if(len(doc)>1):
            pages_to_scan.append(len(doc)-1)

        try:
            for i in pages_to_scan:
                #print(doc.getPageImageList(i))
                for img in doc.getPageImageList(i):
                    #print(img)
                    xref = img[0]
                    pix = fitz.Pixmap(doc, xref)
                    img_name = "./images/%s-%s.png" % (file, i)

                    if pix.n < 5:       # this is GRAY or RGB
                        pix.writePNG(img_name)

                    else:               # CMYK: convert to RGB first
                        pix1 = fitz.Pixmap(fitz.csRGB, pix)
                        pix1.writePNG(img_name)
                        pix1 = None

                    img_text = pytesseract.image_to_string(Image.open(img_name))
                    print(img_text)
                    imgtext_corpus[file].add(img_text)
                    pix = None
        except:
            continue
            
    save_obj('imgtext_corpus.pkl', imgtext_corpus)

# %%
## using tabula package to identify possible tables in a pdf page

import tabula 
file = '[Kotak] Karur Vysya Bank, July 25, 2018.pdf'
df = tabula.read_pdf(source_path+file, pages='1', multiple_tables=True)
print(df)
